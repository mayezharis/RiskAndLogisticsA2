# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
LSH_decreased_distances_random = np.array([[290706, 290352, 289974, 289860, 289794, 289662, 289662],
                                            [290706, 290256, 289752, 289752, 289698, 289698, 289356],
                                            [290706, 289812, 289782, 289752, 289614, 289614, 289614],
                                            [290706, 289332, 289278, 289230, 289032, 288564, 288462],
                                            [290706, 290292, 289686, 289668, 289590, 289482, 289440],
                                            [290706, 290352, 289548, 289362, 288372, 288282, 288252],
                                            [290706, 290664, 290490, 290490, 290460, 290370, 290370],
                                            [290706, 290046, 289896, 289782, 289644, 289608, 289554],
                                            [290706, 290388, 290250, 290166, 289698, 289350, 289350],
                                            [290706, 290598, 290520, 289968, 289806, 289734, 289734]])

nb_empty_shelves = np.arange(7)
initial_distance = np.repeat(290706, 7)

fig, ax = plt.subplots(figsize = (10,5))
for dec in LSH_decreased_distances_random:
    plt.plot(nb_empty_shelves, dec)
plt.plot(nb_empty_shelves, initial_distance, 'k--', label = "Total walking distance with CA")
plt.xlabel("Number of remaining shelves filled", fontsize = 22)
plt.ylabel("Distance (in metres)", fontsize = 22)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.legend(fontsize = 16)
plt.grid()
plt.savefig("Figures/Random_added_shelves.pdf", dpi=300)
plt.show()

# %% [markdown]
# # Tables for local search results
# ### Local search heuristic for Q3

# %%
# Random heuristic with 6 shelves extra
LSH_RandomHeuristic_k10 = np.array([[0., 40.49, 86.49, 136.20, 183.24, 232.14, 276.40, 320.91, 
                                     362.15, 399.79, 445.46, 486.07, 526.73, 568.15, 611.54, 
                                     654.49, 701.67, 749.74, 793.36, 837.48, 881.83, 926.19, 
                                     974.80, 1018.99, 1070.11, 1120.04, 1167.19, 1214.09, 1262.73, 
                                     1310.81, 1376.26, 1444.02, 1501.47, 1570.83, 1646.59, 1732.55, 
                                     1820.67, 1899.51, 1975.49, 2035.95, 2101.37, 2164.59, 2224.74, 
                                     2284.53, 2368.94, 2413.20, 2456.03, 2497.79, 2540.17,
                                     3596.74],
                                     [278652, 274272, 272016, 269466, 267516, 264378, 261582, 
                                      260088, 258822, 257772, 254778, 253860, 252864, 252030, 
                                      251178, 250644, 249690, 246642, 244626, 243054, 242046, 
                                      240570, 239514, 238272, 237894, 237504, 237240, 236988, 
                                      235836, 234852, 234678, 234414, 231942, 231342, 230658, 
                                      228474, 226848, 226218, 225990, 225528, 225060, 224940, 
                                      224784, 224676, 224130, 223044, 222882, 222774, 222684,
                                      222684]])

# Current allocation
LSH_CA_k5 = np.array([[0, 142.31, 282.02, 371.11, 458.65, 587.43, 697.10, 783.90, 884.65, 
                        973.83, 1118.04, 1195.31, 1266.82, 1341.30, 1419.75, 1490.08, 
                        1560.59, 1635.76, 1718.16, 1796.68, 1882.56, 1971.24, 2057.75, 
                        2140.32, 2224.09,  2327.75, 2424.37, 2514.72, 2603.69, 2691.60, 
                        2775.23, 2860.92, 2940.82, 3020.61, 3095.79, 3170.95, 3251.51, 
                        3332.08, 3422.06, 3504.13, 3596.74],
                        [290706, 286110, 281142, 276624, 273486, 270738, 268668, 266598, 
                       264654, 262602, 260274, 258396, 256710, 254670, 251742, 250098, 
                       246102, 244608, 243126, 241740, 240480, 239172, 238038, 235812, 
                       235164, 233694, 233076, 231162, 229500, 228390, 227778, 225444, 
                       224862, 223218, 222804, 222336, 221868, 221544, 221058, 220374, 218664]])

# Greedy heuristic with 6 shelves extra
LSH_GreedyHeuristic_k10 = np.array([[0., 204.64, 431.95, 622.74, 3596.74],[201888, 201558, 201420, 201414, 201414]])

# MCP with 0 extra shelves filled
LSH_MCP_0extra_k10 = np.array([[0, 185.27, 321.20, 438.90, 542.04, 666.60, 779.31, 887.07, 
                                1000.91, 1092.79, 1173.69, 1255.11, 1393.34, 1507.76,
                                3596.74],
                                [205038, 204504, 204342, 204096, 203892, 203754, 203526, 203280, 
                                 203172, 202926, 202596, 202548, 202218, 202164,
                                 202164]])

# MCP with 6 shelves extra filled
LSH_MCP_6extra_k10 = np.array([[0, 183.35, 374.14, 669.19, 919.08, 1142.24, 1421.95, 2082.23, 2544.27, 3596.74],
                               [203808, 203538, 203466, 203370, 203298, 202980, 202896, 202866, 202842, 202842]])

# %% [markdown]
# #### Plots for the LSH results in Q3

# %%
fig, ax = plt.subplots(figsize = (10,5))
plt.plot(LSH_SlightlyGreedyHeuristic_k10[0,:], LSH_SlightlyGreedyHeuristic_k10[1,:], label = "GH")
plt.plot(LSH_MCP_0extra_k10[0,:], LSH_MCP_0extra_k10[1,:], label = "MCP0")
plt.plot(LSH_MCP_6extra_k10[0,:], LSH_MCP_6extra_k10[1,:], label = "MCP6")
plt.plot(LSH_CA_k5[0,:], LSH_CA_k5[1,:], label = "CA")
plt.plot(LSH_RandomHeuristic_k10[0,:], LSH_RandomHeuristic_k10[1,:], label = "Random")
plt.xlabel("Time (in seconds)", fontsize = 22)
plt.ylabel("Distance (in metres)", fontsize = 22)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.legend(fontsize = 16)
plt.grid()
plt.savefig("Figures/All_no_aisles.pdf", dpi=300)
plt.show()

fig, ax = plt.subplots(figsize = (10,5))
plt.plot(LSH_SlightlyGreedyHeuristic_k10[0,:], LSH_SlightlyGreedyHeuristic_k10[1,:], label = "GH")
plt.plot(LSH_MCP_0extra_k10[0,:], LSH_MCP_0extra_k10[1,:], label = "MCP0")
plt.plot(LSH_MCP_6extra_k10[0,:], LSH_MCP_6extra_k10[1,:], label = "MCP6")
plt.xlabel("Time (in seconds)", fontsize = 22)
plt.ylabel("Distance (in metres)", fontsize = 22)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.legend(fontsize = 16)
plt.grid()
plt.savefig("Figures/Heur_no_aisle.pdf", dpi=300)
plt.show()

# %% [markdown]
# ### Local Search Heuristic for Q4

# %%
# CA with 1 mid aisle - 2341.34
LSH_CA_m1 = np.array([[0., 56.34, 109.91, 171.84, 223.15, 271.68, 320.62, 365.46, 414.64, 463.46, 508.39, 558.65, 
                       607.36, 655.55, 703.11, 748.21, 790.79, 835.60, 883.53, 928.64, 973.12, 1017.92, 1062.52, 
                       1111.10, 1159.58, 1224.15, 1305.33, 1355.67, 1404.79, 1453.44, 1501.56, 1545.79, 1590.19, 
                       1637.89, 1685.69, 1733.40, 1780.89, 1827.99, 
                       2341.34, 3596.74],
                       [284820, 277122, 271806, 263046, 259170, 254538, 250506, 247020, 244458, 241752, 240414, 
                        239214, 238104, 237126, 232956, 231948, 229320, 228600, 228006, 227520, 225876, 224916, 
                        223932, 222678, 221676, 220482, 219942, 219396, 215532, 214176, 213774, 211530, 210936, 
                        210576, 209016, 208332, 207612, 207048, 
                        207048, 207048]])

LSH_CA_m2 = np.array([[0., 49.04, 95.68, 141.49, 187.01, 232.61, 276.65, 320.33, 363.47, 409.21, 455.04, 500.83, 
                       546.96, 594.19, 640.83, 686.60, 732.15, 778.50, 833.80, 892.01, 933.36, 980.09, 1026.14, 
                        184794, 184794]])

LSH_MCP0_m2 = np.array([[0., 74.02, 135.93, 201.77, 267.22, 330.99, 393.93, 466.80,
                         767.44, 3596.74],
                        [186066, 185754, 185460, 185280, 185094, 184974, 184896, 184890,
                         184890, 184890]])

LSH_MCP0_m3 = np.array([[0., 70.83, 201.14, 281.14, 360.41, 436.83, 527.21, 611.32, 689.14, 767.44,
                         3596.74],
                        [189336, 189096, 188874, 188700, 188640, 188526, 188490, 188448, 188388, 188328,
                         188328]])

LSH_MCP0_m4 = np.array([[0., 109.84, 197.46, 298.83, 383.78,
                         767.44, 3596.74], 
                         [192162, 191880, 191604, 191568, 191478, 
                          191478, 191478]])

# %%
# MCP 6 - 1256.34
LSH_MCP6_m1 = np.array([[0., 130.80, 283.21, 373.66, 459.85, 530.39, 602.68, 673.56, 741.62,
                            1256.34, 3596.74],
                        [185976, 185706, 185532, 185394, 185082, 185010, 184986, 184974, 184938,
                         184938, 184938]])

LSH_MCP6_m2 = np.array([[0., 171.67, 342.61, 521.15, 731.81, 961.56,
                            1256.34, 3596.74],
                        [186036, 185724, 185442, 185262, 185076, 184992, 
                         184992, 184992]])

LSH_MCP6_m3 = np.array([[0., 187.10, 313.39, 458.55, 621.63, 747.10, 870.36, 974.99, 1108.95, 1256.34,
                         3596.74],
                         [189282, 189066, 188850, 188838, 188790, 188670, 188430, 188088, 188004, 187998,
                         187998]])

LSH_MCP6_m4 = np.array([[0., 121.88, 272.31, 412.31, 544.41, 698.13, 827.64, 955.08, 1097.07, 1235.51,
                            1256.34, 3596.74],
                        [192114, 191844, 191694, 191640, 191604, 191556, 191526, 191364, 191340, 191208,
                         191208, 191208]])

# %%
#  GH - 1510.01
LSH_GH_m1 = np.array([[0., 110.73, 196.39, 330.59, 403.55, 470.01, 538.81, 608.66, 712.34,
                        1510.01, 3596.74],
                      [185514, 185106, 184914, 184848, 184794, 184596, 184560, 184542, 184512,
                       184512, 184512]])

LSH_GH_m2 = np.array([[0., 91.82, 265.80, 426.84, 557.37, 672.31, 797.36, 920.50, 
                       1031.38, 1134.62, 1251.43, 1366.87, 1510.01,
                       3596.74],
                       [185472, 185292, 185136, 185022, 184944, 184902, 
                        184758, 184698, 184656, 184626, 184596, 184524, 184518,
                        184518]])

LSH_GH_m3 = np.array([[0., 121.14, 242.31, 368.43, 478.00,
                        1510.01, 3596.74],
                      [188088, 187926, 187896, 187884, 187638,
                       187638, 187638]])

LSH_GH_m4 = np.array([[0., 102.24,
                        1510.01, 3596.74], 
                      [191106, 190536,
                       190536, 190536]])

# %%
fig, ax = plt.subplots(figsize=(10,5))
plt.plot(LSH_CA_k5[0,:], LSH_CA_k5[1,:], label = "CA")
plt.plot(LSH_CA_m1[0,:], LSH_CA_m1[1,:], label = "CA_1")
plt.plot(LSH_CA_m2[0,:], LSH_CA_m2[1,:], label = "CA_2")
plt.plot(LSH_CA_m3[0,:], LSH_CA_m3[1,:], label = "CA_3")
plt.plot(LSH_CA_m4[0,:], LSH_CA_m4[1,:], label = "CA_4")
plt.xlabel("Time (in seconds)", fontsize = 22)
plt.ylabel("Distance (in metres)", fontsize = 22)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.legend(fontsize = 18)
plt.grid()
plt.savefig("Figures/CA_all_aisles.pdf", dpi=300)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,5))
plt.plot(LSH_MCP_0extra_k10[0,:], LSH_MCP_0extra_k10[1,:], label = "MCP0")
plt.plot(LSH_MCP0_m1[0,:], LSH_MCP0_m1[1,:], label = "MCP0_1")
plt.plot(LSH_MCP0_m2[0,:], LSH_MCP0_m2[1,:], label = "MCP0_2")
plt.plot(LSH_MCP0_m3[0,:], LSH_MCP0_m3[1,:], label = "MCP0_3")
plt.plot(LSH_MCP0_m4[0,:], LSH_MCP0_m4[1,:], label = "MCP0_4")
plt.xlabel("Time (in seconds)", fontsize = 22)
plt.ylabel("Distance (in metres)", fontsize = 22)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.legend(fontsize = 16, loc='right')
plt.grid()
plt.savefig("Figures/MCP0_all_aisles.pdf", dpi=300)
plt.show()

# %%
fig, ax = plt.subplots()
plt.plot(LSH_MCP6_m1[0,:], LSH_MCP6_m1[1,:], label = "MCP6_1")
plt.plot(LSH_MCP6_m2[0,:], LSH_MCP6_m2[1,:], label = "MCP6_2")
plt.plot(LSH_MCP6_m3[0,:], LSH_MCP6_m3[1,:], label = "MCP6_3")
plt.plot(LSH_MCP6_m4[0,:], LSH_MCP6_m4[1,:], label = "MCP6_4")
plt.xlabel("Time (in seconds)", fontsize = 14)
plt.ylabel("Distance (in metres)", fontsize = 14)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.legend(fontsize = 14)
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots()
plt.plot(LSH_GH_m1[0,:-1], LSH_GH_m1[1,:-1], label = "GH_1")
plt.plot(LSH_GH_m2[0,:-1], LSH_GH_m2[1,:-1], label = "GH_2")
plt.plot(LSH_GH_m3[0,:-1], LSH_GH_m3[1,:-1], label = "GH_3")
plt.plot(LSH_GH_m4[0,:-1], LSH_GH_m4[1,:-1], label = "GH_4")
plt.xlabel("Time (in seconds)", fontsize = 14)
plt.ylabel("Distance (in metres)", fontsize = 14)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.legend(fontsize = 14)
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,5))
plt.plot(LSH_GH_m1[0,:], LSH_GH_m1[1,:], label = "GH")
plt.plot(LSH_MCP0_m1[0,:], LSH_MCP0_m1[1,:], label = "MCP0")
plt.plot(LSH_MCP6_m1[0,:], LSH_MCP6_m1[1,:], label = "MCP6")
# plt.plot(LSH_CA_m1[0,:], LSH_CA_m1[1,:], label = "CA")
plt.xlabel("Time (in seconds)", fontsize = 22)
plt.ylabel("Distance (in metres)", fontsize = 22)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.legend(fontsize = 18)
plt.grid()
plt.savefig("Figures/Heur_1_aisle.pdf", dpi=300)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,5))
plt.plot(LSH_GH_m2[0,:], LSH_GH_m2[1,:], label = "GH")
plt.plot(LSH_MCP0_m2[0,:], LSH_MCP0_m2[1,:], label = "MCP0")
plt.plot(LSH_MCP6_m2[0,:], LSH_MCP6_m2[1,:], label = "MCP6")
# plt.plot(LSH_CA_m2[0,:], LSH_CA_m2[1,:], label = "CA")
plt.xlabel("Time (in seconds)", fontsize = 22)
plt.ylabel("Distance (in metres)", fontsize = 22)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.legend(fontsize = 18)
plt.grid()
plt.savefig("Figures/Heur_2_aisle.pdf", dpi=300)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,5))
plt.plot(LSH_GH_m3[0,:], LSH_GH_m3[1,:], label = "GH")
plt.plot(LSH_MCP0_m3[0,:], LSH_MCP0_m3[1,:], label = "MCP0")
plt.plot(LSH_MCP6_m3[0,:], LSH_MCP6_m3[1,:], label = "MCP6")
# plt.plot(LSH_CA_m3[0,:], LSH_CA_m3[1,:], label = "CA")
plt.xlabel("Time (in seconds)", fontsize = 22)
plt.ylabel("Distance (in metres)", fontsize = 22)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.legend(fontsize = 18)
plt.grid()
plt.savefig("Figures/Heur_3_aisle.pdf", dpi=300)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,5))
plt.plot(LSH_GH_m4[0,:], LSH_GH_m4[1,:], label = "GH")
plt.plot(LSH_MCP0_m4[0,:], LSH_MCP0_m4[1,:], label = "MCP0")
plt.plot(LSH_MCP6_m4[0,:], LSH_MCP6_m4[1,:], label = "MCP6")
# plt.plot(LSH_CA_m4[0,:], LSH_CA_m4[1,:], label = "CA")
plt.xlabel("Time (in seconds)", fontsize = 22)
plt.ylabel("Distance (in metres)", fontsize = 22)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.legend(fontsize = 18)
plt.grid()
plt.savefig("Figures/Heur_4_aisle.pdf", dpi=300)
plt.show()
