# %%
import re
import numpy as np
import itertools

# %%
def read_file(filename):
    with open(filename, 'r') as file:
        content = file.read()  # Open the file in read mode

    data = {}  # Initialize data as an empty dictionary

    # Each file has number of inputs under which data is stored as a matrix
    numerical_data = re.findall(r'\[([\d\s.]+)\]', content)  # Extract values following each header as numerical values and remove '\t's and '\n's

    sections = ['Orders', 'Allocations', 'DistanceShelfShelf', 'DistancePackagingShelf', 'FullDistanceMatrix']

    for i, section in enumerate(sections):
        data[section] = []
        lines = numerical_data[i].strip().split('\n')
        for line in lines:
            values = line.strip().split()  # Split using spaces
            data[section].append([int(val) for val in values])  # Assuming all values are integers

    return data

# %% [markdown]
# # Reading in data and running the entire function

# %%
filename = r"Xpress Data Files/Data_Xpress_FullDist_Metres.txt"
data = read_file(filename)

# Extracting data into arrays
Orders = data.get('Orders')
Allocations = np.asarray(data.get('Allocations')[0])
DistanceShelfShelf = np.asarray(data.get('DistanceShelfShelf'))
FullDistanceMatrix = np.asarray(data.get('FullDistanceMatrix'))

NbShelves = 96
Shelves = range(1, NbShelves + 1)

FullDistanceMatrix = np.roll(FullDistanceMatrix, shift = 1, axis = 1)
FullDistanceMatrix = np.roll(FullDistanceMatrix, shift = 1, axis = 0)


# testing for allocation vector where every shelf is filled
allocations_full = [45, 79, 39, 68, 73, 53, 19, 44, 16, 71, 27, 41,  2, 46, 60, 67, 56, 
                    83, 80, 57, 69, 55, 75, 34, 89, 12, 81, 62, 23, 26, 24, 86,  3, 17,
                    90, 58, 51, 25, 85, 65, 31, 11, 87, 10, 13, 70, 35, 32, 47,  6, 30,
                    21, 43, 64, 66, 78, 76, 61,  8, 72, 22, 18, 82, 14, 28,  4,  5, 84,
                    54, 48, 63, 29, 49, 74, 37, 36, 20, 38, 50,  7, 88,  9, 40, 77, 15,
                    1, 33, 59, 42, 52,  45, 79, 39, 68, 73, 53]


# testing where only some of the extra shelves are filled
allocations_mid_full = [45, 79, 39, 68, 73, 53, 19, 44, 16, 71, 27, 41,  2, 46, 60, 67, 56, 
                        83, 80, 57, 69, 55, 75, 34, 89, 12, 81, 62, 23, 26, 24, 86,  3, 17,
                        90, 58, 51, 25, 85, 65, 31, 11, 87, 10, 13, 70, 35, 32, 47,  6, 30,
                        21, 43, 64, 66, 78, 76, 61,  8, 72, 22, 18, 82, 14, 28,  4,  5, 84,
                        54, 48, 63, 29, 49, 74, 37, 36, 20, 38, 50,  7, 88,  9, 40, 77, 15,
                        1, 33, 59, 42, 52,  45, 79,  0, 68,  0, 53]

# %%
Allocations
# Out:
# array([45, 79, 39, 68, 73, 53, 19, 44, 16, 71, 27, 41,  2, 46, 60, 67, 56,
#        83, 80, 57, 69, 55, 75, 34, 89, 12, 81, 62, 23, 26, 24, 86,  3, 17,
#        90, 58, 51, 25, 85, 65, 31, 11, 87, 10, 13, 70, 35, 32, 47,  6, 30,
#        21, 43, 64, 66, 78, 76, 61,  8, 72, 22, 18, 82, 14, 28,  4,  5, 84,
#        54, 48, 63, 29, 49, 74, 37, 36, 20, 38, 50,  7, 88,  9, 40, 77, 15,
#         1, 33, 59, 42, 52,  0,  0,  0,  0,  0,  0])

# %%
def q1_function(allocation_vector, DistancesMatrix):
    def find_closest_product(current_position, products, distances):
        closest_product = None
        min_distance = float('inf')
        for product in products:
            if distances[current_position][product] <= min_distance:
                closest_product = product
                min_distance = distances[current_position][product]
        return closest_product

    def generate_order_lists(order):
        ''' 
        Takes a list with tuple elements and returns a list of lists 
        with all possible combinations of individual elements individual elements.
        '''
        order_lists = []
        tuple_indices = [i for i, item in enumerate(order) if isinstance(item, tuple)]
        for combination in itertools.product(*[order[i] for i in tuple_indices]):
            new_order = order.copy()
            for i, index in enumerate(tuple_indices):
                new_order[index] = combination[i]
            order_lists.append(new_order)
        return order_lists

    def greedy_order_route(order, distances):
        ''' 
        Uses a greedy method of calculating the minimum distance. 

        Function has been split into two if statements to consider
        cases of orders where products are contained on more than one shelf.

        If products are contained on more than one shelf, the function constructs 
        a route with all possible shelf combinations and chooses the one with 
        the shortest distance.

        Returns a list containing the route and the total distance for the order.
        '''

        # If all products in the order are contained on one shelf only
        if not any(isinstance(product, tuple) for product in order):
            visited = [0]
            current_position = 0  
            for k in range(len(order)):
                    closest_product = find_closest_product(current_position, order, distances)
                    visited.append(closest_product)
                    order.remove(closest_product)
                    current_position = closest_product
            visited.append(0)
            OrderDistance = 0
            for i in range(len(visited) - 1):
                OrderDistance += distances[visited[i]][visited[i+1]]
            order_distance_final = OrderDistance
            visited_final = visited

        # If one or more products in the order are contained on more than one shelf
        elif any(isinstance(product, tuple) for product in order):
            order_combinations = generate_order_lists(order) # create new orders with all possible combinations from tuples
            order_routes = []   # initialise a list of routes for all combinations                                 
            order_distances = [] # initialise a list of distances for all combinations
            
            # loop over all combinations
            for order in order_combinations:
                visited = [0]
                current_position = 0  
                for k in range(len(order)):
                    closest_product = find_closest_product(current_position, order, distances)
                    visited.append(closest_product)
                    order.remove(closest_product)
                    current_position = closest_product
                visited.append(0)
                order_routes.append(visited) # add the route for the combination to the list of routes
                OrderDistance = 0
                for i in range(len(visited) - 1):
                    OrderDistance += distances[visited[i]][visited[i+1]]
                order_distances.append(OrderDistance) # add the distance for the combination to the list of distances
            
            # select the order with the shortest distance among the combinations
            min_idx = order_distances.index(min(order_distances))
            visited_final = order_routes[min_idx] 
            order_distance_final = order_distances[min_idx]
                
        return visited_final, order_distance_final # return order route and distance
    
    def convert_orders_to_shelf_indices(allocations):
        ''' 
        This function takes the allocation vector and returns an 
        order matrix with shelf indices instead of product indices.
        '''
        product_to_shelf = {}
        for shelf_index, product in enumerate(allocations):
            if product != 0:  # Check if the element is not zero
                if product not in product_to_shelf:
                    product_to_shelf[product] = [shelf_index + 1]  # Initialize with a list containing the current shelf index
                else:
                    # If the product already exists in the dictionary, append the new shelf index to the list
                    product_to_shelf[product].append(shelf_index + 1)

        # Convert product_to_shelf dictionary to a list of tuples if the product is assigned to multiple shelves
        product_to_shelf_tuples = {k: tuple(v) if len(v) > 1 else v[0] for k, v in product_to_shelf.items()}

        OrdersByShelf = []
        for order in Orders:
            order_shelf_indices = []
            for product_index in order:
                if product_index in product_to_shelf_tuples:
                    shelf_indices = product_to_shelf_tuples[product_index]
                    order_shelf_indices.append(shelf_indices)
                else:
                    order_shelf_indices.append(0)  # Product not found in allocation matrix
            OrdersByShelf.append(order_shelf_indices)

        return OrdersByShelf
    

    OrdersByShelf = convert_orders_to_shelf_indices(allocation_vector)
    TotalDistance = 0           # initialise counter for total distance
    DistancesPerOrder = []      # initalise list to contain the distances for each order 
    routes = []                 # intialise list to contain the routes for each order
    for order in OrdersByShelf:
        visited_order_route, visited_order_dist = greedy_order_route(order, DistancesMatrix)
        routes.append(visited_order_route)
        DistancesPerOrder.append(visited_order_dist)
        TotalDistance += visited_order_dist

    # Replace DistancesPerOrder in the return statement with this if you want sorted distances to be returned
    SortedDistancesPerOrder = sorted(DistancesPerOrder, reverse=True)

    # The indices corresponding to the longest orders (descending order) 
    idx_longest_orders = sorted(range(len(DistancesPerOrder)), key=lambda i: DistancesPerOrder[i], reverse=True)
    
    return TotalDistance, DistancesPerOrder, SortedDistancesPerOrder, idx_longest_orders, routes

# %%
### TEST CASE ON CURRENT ALLOCATION ###
TotalDistance, DistancesPerOrder, SortedDistancesPerOrder, idx_longest_orders, routes = q1_function(Allocations)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 ### TEST CASE ON CURRENT ALLOCATION ###
# ----> 2 TotalDistance, DistancesPerOrder, SortedDistancesPerOrder, idx_longest_orders, routes = q1_function(Allocations)
#
# TypeError: q1_function() missing 1 required positional argument: 'DistancesMatrix'

# %% [markdown]
# #### Obtaining total distances for different allocations

# %%
print(f"Distance for the current allocation: {q1_function(Allocations)[0]} metres.")
print(f"Distance for all shelves filled: {q1_function(allocations_full)[0]} metres.")
print(f"Distance for some repeated products and some empty shelves: {q1_function(allocations_mid_full)[0]} metres.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(f"Distance for the current allocation: {q1_function(Allocations)[0]} metres.")
#       2 print(f"Distance for all shelves filled: {q1_function(allocations_full)[0]} metres.")
#       3 print(f"Distance for some repeated products and some empty shelves: {q1_function(allocations_mid_full)[0]} metres.")
#
# TypeError: q1_function() missing 1 required positional argument: 'DistancesMatrix'

# %%
number_to_fill = 1000

# Number of rows and columns to add
num_rows_to_add = 96
num_cols_to_add = 96


# Create a new row filled with the specified number
new_row = np.full((1, FullDistanceMatrix.shape[1]), number_to_fill)

# Repeat the new row to match the number of rows to add
new_rows = np.repeat(new_row, num_rows_to_add, axis=0)

# Concatenate the existing array with the new rows
result_array = np.concatenate((FullDistanceMatrix, new_rows), axis=0)

new_column = np.full((result_array.shape[0], 1), number_to_fill)
new_columns = np.repeat(new_column, num_cols_to_add, axis=1)

result_array = np.concatenate((result_array, new_columns), axis=1)


print(result_array)

print([x +96 for x in Allocations])
# Out:
# [[   0    6    9 ... 1000 1000 1000]
#  [   6    0    3 ... 1000 1000 1000]
#  [   9    3    0 ... 1000 1000 1000]
#  ...
#  [1000 1000 1000 ... 1000 1000 1000]
#  [1000 1000 1000 ... 1000 1000 1000]
#  [1000 1000 1000 ... 1000 1000 1000]]
# [141, 175, 135, 164, 169, 149, 115, 140, 112, 167, 123, 137, 98, 142, 156, 163, 152, 179, 176, 153, 165, 151, 171, 130, 185, 108, 177, 158, 119, 122, 120, 182, 99, 113, 186, 154, 147, 121, 181, 161, 127, 107, 183, 106, 109, 166, 131, 128, 143, 102, 126, 117, 139, 160, 162, 174, 172, 157, 104, 168, 118, 114, 178, 110, 124, 100, 101, 180, 150, 144, 159, 125, 145, 170, 133, 132, 116, 134, 146, 103, 184, 105, 136, 173, 111, 97, 129, 155, 138, 148, 96, 96, 96, 96, 96, 96]

# %%
def addTemporaryFarAwayShelves(Distances):
    #This adds the temporary shelves that are super far away from everything else to the distances matrix
    number_to_fill = 100

    # Number of rows and columns to add
    num_rows_to_add = 90
    num_cols_to_add = 90


    # Create a new row filled with the specified number
    new_row = np.full((1, FullDistanceMatrix.shape[1]), number_to_fill)

    # Repeat the new row to match the number of rows to add
    new_rows = np.repeat(new_row, num_rows_to_add, axis=0)

    # Concatenate the existing array with the new rows
    result_array = np.concatenate((FullDistanceMatrix, new_rows), axis=0)

    new_column = np.full((result_array.shape[0], 1), number_to_fill)
    new_columns = np.repeat(new_column, num_cols_to_add, axis=1)

    result_array = np.concatenate((result_array, new_columns), axis=1)

    return result_array


def slightlyGreedy_ConstructionHeuristic(Distances):
    refilledProducts = False
    tempProducts = [i for i in range(1, 91)]

    tempDistances = addTemporaryFarAwayShelves(Distances)

    normalShelves = [0]*96
    extraShelves = [x for x in range(1, 91)]

    tempAllocations = normalShelves.copy() + extraShelves.copy()

    for shelf in range(96):

        mostReduced = np.inf
        bestP = None
        
        tempShelves = tempAllocations.copy()
        baseline = q1_function(tempShelves, tempDistances)[0]

        for p in tempProducts:
            
            tempShelves = tempAllocations.copy()
            tempShelves[shelf] = p

            newobj = q1_function(tempShelves, tempDistances)

            reduction = newobj[0] - baseline

            if reduction <= mostReduced:
                bestP = p
                mostReduced = reduction

        tempAllocations[shelf] = bestP

        tempProducts.remove(bestP)

        if refilledProducts == False:
            indexOfBestP_onExtraShelf = tempAllocations[96:].index(bestP)
            del tempAllocations[indexOfBestP_onExtraShelf+96]

        if len(tempProducts) == 0:
            tempProducts = [i for i in range(1, 91)]
            refilledProducts = True

        

        print(f"Assigned product {bestP} -> shelf {shelf+1}")

    return tempAllocations

# %%
results = slightlyGreedy_ConstructionHeuristic(FullDistanceMatrix)
# Out:
# Assigned product 34 -> shelf 1
# Assigned product 31 -> shelf 2
# Assigned product 35 -> shelf 3
# Assigned product 71 -> shelf 4
# Assigned product 70 -> shelf 5
# Assigned product 15 -> shelf 6
# Assigned product 18 -> shelf 7
# Assigned product 30 -> shelf 8
# Assigned product 2 -> shelf 9
# Assigned product 51 -> shelf 10
# Assigned product 76 -> shelf 11
# Assigned product 58 -> shelf 12
# Assigned product 67 -> shelf 13
# Assigned product 6 -> shelf 14
# Assigned product 49 -> shelf 15
# Assigned product 50 -> shelf 16
# Assigned product 83 -> shelf 17
# Assigned product 4 -> shelf 18
# Assigned product 11 -> shelf 19
# Assigned product 28 -> shelf 20
# Assigned product 10 -> shelf 21
# Assigned product 38 -> shelf 22
# Assigned product 48 -> shelf 23
# Assigned product 33 -> shelf 24
# Assigned product 52 -> shelf 25
# Assigned product 60 -> shelf 26
# Assigned product 78 -> shelf 27
# Assigned product 43 -> shelf 28
# Assigned product 8 -> shelf 29
# Assigned product 55 -> shelf 30
# Assigned product 63 -> shelf 31
# Assigned product 1 -> shelf 32
# Assigned product 19 -> shelf 33
# Assigned product 13 -> shelf 34
# Assigned product 44 -> shelf 35
# Assigned product 47 -> shelf 36
# Assigned product 39 -> shelf 37
# Assigned product 59 -> shelf 38
# Assigned product 57 -> shelf 39
# Assigned product 66 -> shelf 40
# Assigned product 72 -> shelf 41
# Assigned product 46 -> shelf 42
# Assigned product 37 -> shelf 43
# Assigned product 84 -> shelf 44
# Assigned product 64 -> shelf 45
# Assigned product 74 -> shelf 46
# Assigned product 65 -> shelf 47
# Assigned product 32 -> shelf 48
# Assigned product 20 -> shelf 49
# Assigned product 69 -> shelf 50
# Assigned product 68 -> shelf 51
# Assigned product 16 -> shelf 52
# Assigned product 29 -> shelf 53
# Assigned product 90 -> shelf 54
# Assigned product 77 -> shelf 55
# Assigned product 82 -> shelf 56
# Assigned product 89 -> shelf 57
# Assigned product 79 -> shelf 58
# Assigned product 21 -> shelf 59
# Assigned product 45 -> shelf 60
# Assigned product 87 -> shelf 61
# Assigned product 22 -> shelf 62
# Assigned product 27 -> shelf 63
# Assigned product 88 -> shelf 64
# Assigned product 24 -> shelf 65
# Assigned product 54 -> shelf 66
# Assigned product 5 -> shelf 67
# Assigned product 36 -> shelf 68
# Assigned product 80 -> shelf 69
# Assigned product 23 -> shelf 70
# Assigned product 14 -> shelf 71
# Assigned product 9 -> shelf 72
# Assigned product 56 -> shelf 73
# Assigned product 75 -> shelf 74
# Assigned product 53 -> shelf 75
# Assigned product 61 -> shelf 76
# Assigned product 12 -> shelf 77
# Assigned product 25 -> shelf 78
# Assigned product 40 -> shelf 79
# Assigned product 62 -> shelf 80
# Assigned product 26 -> shelf 81
# Assigned product 3 -> shelf 82
# Assigned product 41 -> shelf 83
# Assigned product 86 -> shelf 84
# Assigned product 73 -> shelf 85
# Assigned product 85 -> shelf 86
# Assigned product 7 -> shelf 87
# Assigned product 42 -> shelf 88
# Assigned product 81 -> shelf 89
# Assigned product 17 -> shelf 90
# Assigned product 38 -> shelf 91
# Assigned product 33 -> shelf 92
# Assigned product 35 -> shelf 93
# Assigned product 31 -> shelf 94
# Assigned product 16 -> shelf 95
# Assigned product 71 -> shelf 96

# %%
greedyAllocation = results.copy()

# %%
results = q1_function(results, FullDistanceMatrix)
for i, order in enumerate(Orders):
    print(f"order {order} picked in dist {results[1][i]} taking route {results[4][i]}")
# Out:
# order [50, 30, 0, 0, 0] picked in dist 102 taking route [0, 0, 0, 0, 8, 16, 0]
# order [49, 18, 76, 0, 0] picked in dist 96 taking route [0, 0, 0, 7, 11, 15, 0]
# order [72, 52, 51, 41, 35] picked in dist 168 taking route [0, 25, 3, 10, 41, 83, 0]
# order [50, 4, 0, 0, 0] picked in dist 114 taking route [0, 0, 0, 0, 16, 18, 0]
# order [76, 19, 26, 80, 6] picked in dist 168 taking route [0, 33, 11, 14, 69, 81, 0]
# order [66, 67, 51, 84, 71] picked in dist 126 taking route [0, 4, 10, 13, 40, 44, 0]
# order [39, 18, 29, 83, 49] picked in dist 150 taking route [0, 53, 7, 37, 15, 17, 0]
# order [88, 2, 0, 0, 0] picked in dist 168 taking route [0, 0, 0, 0, 9, 64, 0]
# order [63, 19, 0, 0, 0] picked in dist 60 taking route [0, 0, 0, 0, 31, 33, 0]
# order [28, 11, 77, 8, 31] picked in dist 168 taking route [0, 2, 29, 19, 20, 55, 0]
# order [32, 78, 38, 31, 44] picked in dist 150 taking route [0, 2, 27, 35, 22, 48, 0]
# order [63, 31, 10, 68, 30] picked in dist 162 taking route [0, 2, 31, 8, 21, 51, 0]
# order [88, 70, 35, 2, 0] picked in dist 168 taking route [0, 0, 3, 5, 9, 64, 0]
# order [71, 70, 77, 34, 78] picked in dist 90 taking route [0, 1, 27, 4, 5, 55, 0]
# order [38, 8, 15, 90, 0] picked in dist 168 taking route [0, 0, 29, 6, 54, 91, 0]
# order [6, 22, 63, 0, 0] picked in dist 168 taking route [0, 0, 0, 31, 14, 62, 0]
# order [29, 2, 38, 0, 0] picked in dist 168 taking route [0, 0, 0, 53, 91, 9, 0]
# order [15, 59, 0, 0, 0] picked in dist 90 taking route [0, 0, 0, 0, 6, 38, 0]
# order [8, 39, 51, 34, 89] picked in dist 150 taking route [0, 1, 29, 10, 37, 57, 0]
# order [75, 31, 48, 70, 71] picked in dist 192 taking route [0, 74, 4, 5, 23, 94, 0]
# order [10, 71, 0, 0, 0] picked in dist 132 taking route [0, 0, 0, 0, 4, 21, 0]
# order [74, 15, 0, 0, 0] picked in dist 138 taking route [0, 0, 0, 0, 6, 46, 0]
# order [44, 15, 0, 0, 0] picked in dist 72 taking route [0, 0, 0, 0, 6, 35, 0]
# order [51, 0, 0, 0, 0] picked in dist 66 taking route [0, 0, 0, 0, 0, 10, 0]
# order [19, 65, 50, 67, 0] picked in dist 144 taking route [0, 0, 33, 13, 16, 47, 0]
# order [48, 5, 88, 71, 67] picked in dist 168 taking route [0, 4, 13, 23, 67, 64, 0]
# order [30, 39, 6, 31, 0] picked in dist 90 taking route [0, 0, 2, 8, 37, 14, 0]
# order [13, 0, 0, 0, 0] picked in dist 66 taking route [0, 0, 0, 0, 0, 34, 0]
# order [58, 0, 0, 0, 0] picked in dist 78 taking route [0, 0, 0, 0, 0, 12, 0]
# order [6, 0, 0, 0, 0] picked in dist 90 taking route [0, 0, 0, 0, 0, 14, 0]
# order [63, 48, 0, 0, 0] picked in dist 144 taking route [0, 0, 0, 0, 31, 23, 0]
# order [18, 15, 70, 2, 0] picked in dist 60 taking route [0, 0, 5, 6, 7, 9, 0]
# order [64, 6, 0, 0, 0] picked in dist 132 taking route [0, 0, 0, 0, 14, 45, 0]
# order [83, 82, 18, 35, 38] picked in dist 168 taking route [0, 3, 7, 17, 22, 56, 0]
# order [63, 79, 8, 0, 0] picked in dist 120 taking route [0, 0, 0, 29, 31, 58, 0]
# order [58, 55, 44, 72, 47] picked in dist 108 taking route [0, 30, 35, 36, 12, 41, 0]
# order [28, 0, 0, 0, 0] picked in dist 126 taking route [0, 0, 0, 0, 0, 20, 0]
# order [49, 16, 55, 10, 0] picked in dist 168 taking route [0, 0, 52, 30, 15, 21, 0]
# order [76, 65, 2, 0, 0] picked in dist 144 taking route [0, 0, 0, 9, 11, 47, 0]
# order [70, 51, 9, 76, 13] picked in dist 168 taking route [0, 5, 34, 10, 11, 72, 0]
# order [71, 28, 10, 15, 11] picked in dist 132 taking route [0, 4, 6, 19, 20, 21, 0]
# order [74, 83, 76, 0, 0] picked in dist 138 taking route [0, 0, 0, 11, 17, 46, 0]
# order [15, 0, 0, 0, 0] picked in dist 42 taking route [0, 0, 0, 0, 0, 6, 0]
# order [26, 83, 35, 0, 0] picked in dist 168 taking route [0, 0, 0, 3, 17, 81, 0]
# order [19, 67, 48, 78, 72] picked in dist 144 taking route [0, 27, 33, 13, 41, 23, 0]
# order [45, 89, 59, 9, 25] picked in dist 168 taking route [0, 78, 57, 60, 72, 38, 0]
# order [31, 2, 15, 67, 0] picked in dist 84 taking route [0, 0, 2, 6, 9, 13, 0]
# order [34, 60, 0, 0, 0] picked in dist 18 taking route [0, 0, 0, 0, 1, 26, 0]
# order [39, 33, 48, 19, 46] picked in dist 150 taking route [0, 33, 37, 42, 23, 24, 0]
# order [2, 0, 0, 0, 0] picked in dist 60 taking route [0, 0, 0, 0, 0, 9, 0]
# order [30, 58, 55, 35, 31] picked in dist 78 taking route [0, 2, 3, 30, 8, 12, 0]
# order [15, 59, 4, 0, 0] picked in dist 114 taking route [0, 0, 0, 6, 38, 18, 0]
# order [30, 64, 78, 0, 0] picked in dist 132 taking route [0, 0, 0, 27, 8, 45, 0]
# order [31, 32, 34, 0, 0] picked in dist 150 taking route [0, 0, 0, 1, 2, 48, 0]
# order [37, 71, 72, 55, 0] picked in dist 120 taking route [0, 0, 4, 30, 41, 43, 0]
# order [30, 54, 31, 22, 0] picked in dist 168 taking route [0, 0, 8, 94, 66, 62, 0]
# order [21, 15, 0, 0, 0] picked in dist 120 taking route [0, 0, 0, 0, 6, 59, 0]
# order [31, 70, 0, 0, 0] picked in dist 36 taking route [0, 0, 0, 0, 2, 5, 0]
# order [50, 58, 71, 25, 35] picked in dist 150 taking route [0, 3, 4, 12, 16, 78, 0]
# order [68, 54, 2, 83, 0] picked in dist 198 taking route [0, 0, 51, 9, 17, 66, 0]
# order [48, 73, 22, 38, 43] picked in dist 168 taking route [0, 28, 22, 23, 62, 85, 0]
# order [56, 0, 0, 0, 0] picked in dist 18 taking route [0, 0, 0, 0, 0, 73, 0]
# order [77, 76, 83, 0, 0] picked in dist 162 taking route [0, 0, 0, 55, 11, 17, 0]
# order [90, 11, 31, 0, 0] picked in dist 168 taking route [0, 0, 0, 54, 94, 19, 0]
# order [58, 0, 0, 0, 0] picked in dist 78 taking route [0, 0, 0, 0, 0, 12, 0]
# order [52, 48, 78, 76, 0] picked in dist 144 taking route [0, 0, 25, 27, 11, 23, 0]
# order [18, 15, 0, 0, 0] picked in dist 48 taking route [0, 0, 0, 0, 6, 7, 0]
# order [70, 64, 31, 84, 42] picked in dist 168 taking route [0, 2, 5, 44, 45, 88, 0]
# order [48, 4, 50, 0, 0] picked in dist 144 taking route [0, 0, 0, 16, 18, 23, 0]
# order [40, 39, 59, 89, 0] picked in dist 156 taking route [0, 0, 79, 57, 37, 38, 0]
# order [34, 19, 0, 0, 0] picked in dist 60 taking route [0, 0, 0, 0, 1, 33, 0]
# order [71, 57, 4, 88, 22] picked in dist 168 taking route [0, 4, 39, 18, 64, 62, 0]
# order [59, 72, 0, 0, 0] picked in dist 108 taking route [0, 0, 0, 0, 38, 41, 0]
# order [67, 38, 47, 18, 0] picked in dist 138 taking route [0, 0, 7, 36, 13, 22, 0]
# order [78, 60, 49, 15, 71] picked in dist 96 taking route [0, 26, 27, 4, 6, 15, 0]
# order [58, 71, 83, 15, 67] picked in dist 108 taking route [0, 4, 6, 12, 13, 17, 0]
# order [28, 18, 78, 0, 0] picked in dist 126 taking route [0, 0, 0, 27, 7, 20, 0]
# order [63, 4, 0, 0, 0] picked in dist 114 taking route [0, 0, 0, 0, 31, 18, 0]
# order [32, 0, 0, 0, 0] picked in dist 150 taking route [0, 0, 0, 0, 0, 48, 0]
# order [58, 2, 31, 1, 46] picked in dist 114 taking route [0, 2, 32, 9, 12, 42, 0]
# order [71, 39, 0, 0, 0] picked in dist 84 taking route [0, 0, 0, 0, 4, 37, 0]
# order [13, 0, 0, 0, 0] picked in dist 66 taking route [0, 0, 0, 0, 0, 34, 0]
# order [43, 6, 18, 19, 71] picked in dist 90 taking route [0, 4, 28, 7, 33, 14, 0]
# order [51, 43, 11, 28, 18] picked in dist 126 taking route [0, 28, 7, 10, 19, 20, 0]
# order [48, 51, 0, 0, 0] picked in dist 144 taking route [0, 0, 0, 0, 10, 23, 0]
# order [18, 52, 83, 88, 15] picked in dist 168 taking route [0, 25, 6, 7, 17, 64, 0]
# order [33, 70, 0, 0, 0] picked in dist 150 taking route [0, 0, 0, 0, 5, 24, 0]
# order [84, 49, 82, 35, 15] picked in dist 168 taking route [0, 3, 6, 15, 44, 56, 0]
# order [83, 13, 50, 27, 0] picked in dist 168 taking route [0, 0, 34, 16, 17, 63, 0]
# order [15, 0, 0, 0, 0] picked in dist 42 taking route [0, 0, 0, 0, 0, 6, 0]
# order [18, 33, 0, 0, 0] picked in dist 150 taking route [0, 0, 0, 0, 7, 24, 0]
# order [31, 63, 0, 0, 0] picked in dist 48 taking route [0, 0, 0, 0, 2, 31, 0]
# order [50, 39, 51, 83, 0] picked in dist 108 taking route [0, 0, 10, 37, 16, 17, 0]
# order [14, 0, 0, 0, 0] picked in dist 150 taking route [0, 0, 0, 0, 0, 71, 0]
# order [39, 76, 71, 2, 0] picked in dist 84 taking route [0, 0, 4, 9, 11, 37, 0]
# order [69, 31, 15, 8, 21] picked in dist 120 taking route [0, 2, 29, 6, 50, 59, 0]
# order [35, 31, 70, 11, 72] picked in dist 120 taking route [0, 2, 3, 5, 41, 19, 0]
# order [77, 34, 60, 78, 38] picked in dist 150 taking route [0, 1, 26, 27, 55, 91, 0]
# order [35, 48, 0, 0, 0] picked in dist 144 taking route [0, 0, 0, 0, 3, 23, 0]
# order [76, 32, 35, 13, 0] picked in dist 150 taking route [0, 0, 3, 34, 11, 48, 0]
# order [45, 32, 44, 79, 49] picked in dist 168 taking route [0, 58, 60, 48, 15, 35, 0]
# order [43, 87, 45, 11, 8] picked in dist 168 taking route [0, 28, 29, 19, 61, 60, 0]
# order [84, 0, 0, 0, 0] picked in dist 126 taking route [0, 0, 0, 0, 0, 44, 0]
# order [15, 29, 72, 0, 0] picked in dist 150 taking route [0, 0, 0, 53, 6, 41, 0]
# order [17, 34, 76, 30, 6] picked in dist 168 taking route [0, 1, 8, 11, 14, 90, 0]
# order [11, 0, 0, 0, 0] picked in dist 120 taking route [0, 0, 0, 0, 0, 19, 0]
# order [11, 6, 0, 0, 0] picked in dist 120 taking route [0, 0, 0, 0, 14, 19, 0]
# order [89, 15, 31, 0, 0] picked in dist 108 taking route [0, 0, 0, 2, 6, 57, 0]
# order [19, 31, 2, 26, 82] picked in dist 126 taking route [0, 2, 9, 33, 56, 81, 0]
# order [34, 71, 48, 2, 35] picked in dist 144 taking route [0, 1, 3, 4, 9, 23, 0]
# order [4, 31, 43, 13, 59] picked in dist 114 taking route [0, 2, 28, 34, 38, 18, 0]
# order [30, 60, 16, 14, 15] picked in dist 168 taking route [0, 26, 6, 8, 71, 95, 0]
# order [18, 0, 0, 0, 0] picked in dist 48 taking route [0, 0, 0, 0, 0, 7, 0]
# order [60, 55, 78, 0, 0] picked in dist 42 taking route [0, 0, 0, 26, 27, 30, 0]
# order [15, 63, 4, 78, 83] picked in dist 114 taking route [0, 27, 6, 31, 17, 18, 0]
# order [35, 69, 75, 61, 0] picked in dist 60 taking route [0, 0, 74, 50, 76, 3, 0]
# order [31, 18, 0, 0, 0] picked in dist 48 taking route [0, 0, 0, 0, 2, 7, 0]
# order [34, 49, 0, 0, 0] picked in dist 96 taking route [0, 0, 0, 0, 1, 15, 0]
# order [87, 0, 0, 0, 0] picked in dist 90 taking route [0, 0, 0, 0, 0, 61, 0]
# order [35, 72, 83, 67, 0] picked in dist 108 taking route [0, 0, 3, 13, 17, 41, 0]
# order [10, 27, 43, 83, 11] picked in dist 168 taking route [0, 28, 17, 19, 21, 63, 0]
# order [29, 1, 90, 0, 0] picked in dist 102 taking route [0, 0, 0, 53, 54, 32, 0]
# order [18, 76, 38, 58, 34] picked in dist 138 taking route [0, 1, 7, 11, 12, 22, 0]
# order [13, 49, 58, 35, 51] picked in dist 96 taking route [0, 3, 10, 34, 12, 15, 0]
# order [10, 39, 0, 0, 0] picked in dist 132 taking route [0, 0, 0, 0, 37, 21, 0]
# order [71, 70, 0, 0, 0] picked in dist 36 taking route [0, 0, 0, 0, 4, 5, 0]
# order [51, 38, 18, 76, 78] picked in dist 138 taking route [0, 27, 7, 10, 11, 22, 0]
# order [70, 59, 71, 55, 72] picked in dist 108 taking route [0, 4, 5, 30, 38, 41, 0]
# order [34, 2, 0, 0, 0] picked in dist 60 taking route [0, 0, 0, 0, 1, 9, 0]
# order [50, 11, 10, 72, 44] picked in dist 132 taking route [0, 35, 16, 41, 19, 21, 0]
# order [51, 18, 64, 49, 2] picked in dist 132 taking route [0, 7, 9, 10, 15, 45, 0]
# order [34, 31, 0, 0, 0] picked in dist 18 taking route [0, 0, 0, 0, 1, 2, 0]
# order [74, 43, 76, 89, 67] picked in dist 168 taking route [0, 28, 11, 13, 46, 57, 0]
# order [44, 0, 0, 0, 0] picked in dist 72 taking route [0, 0, 0, 0, 0, 35, 0]
# order [76, 57, 67, 6, 58] picked in dist 96 taking route [0, 11, 12, 13, 14, 39, 0]
# order [34, 24, 66, 0, 0] picked in dist 168 taking route [0, 0, 0, 1, 40, 65, 0]
# order [4, 34, 0, 0, 0] picked in dist 114 taking route [0, 0, 0, 0, 1, 18, 0]
# order [2, 15, 51, 83, 13] picked in dist 108 taking route [0, 6, 9, 34, 10, 17, 0]
# order [5, 16, 38, 18, 13] picked in dist 168 taking route [0, 7, 34, 22, 95, 67, 0]
# order [67, 47, 20, 71, 0] picked in dist 102 taking route [0, 0, 49, 4, 36, 13, 0]
# order [10, 30, 15, 28, 0] picked in dist 132 taking route [0, 0, 6, 8, 20, 21, 0]
# order [49, 51, 0, 0, 0] picked in dist 96 taking route [0, 0, 0, 0, 10, 15, 0]
# order [21, 37, 13, 18, 35] picked in dist 168 taking route [0, 3, 7, 34, 43, 59, 0]
# order [10, 18, 35, 31, 0] picked in dist 132 taking route [0, 0, 2, 3, 7, 21, 0]
# order [37, 48, 0, 0, 0] picked in dist 144 taking route [0, 0, 0, 0, 43, 23, 0]
# order [65, 4, 31, 13, 0] picked in dist 144 taking route [0, 0, 2, 34, 18, 47, 0]
# order [57, 55, 2, 66, 0] picked in dist 102 taking route [0, 0, 30, 9, 39, 40, 0]
# order [55, 39, 1, 0, 0] picked in dist 84 taking route [0, 0, 0, 30, 32, 37, 0]
# order [49, 5, 70, 43, 16] picked in dist 168 taking route [0, 28, 5, 15, 67, 52, 0]
# order [31, 58, 30, 0, 0] picked in dist 78 taking route [0, 0, 0, 2, 8, 12, 0]
# order [31, 83, 16, 6, 34] picked in dist 162 taking route [0, 1, 2, 52, 14, 17, 0]
# order [31, 76, 9, 0, 0] picked in dist 168 taking route [0, 0, 0, 2, 11, 72, 0]
# order [79, 10, 54, 66, 0] picked in dist 168 taking route [0, 0, 58, 66, 21, 40, 0]
# order [51, 64, 31, 70, 82] picked in dist 168 taking route [0, 2, 5, 10, 45, 56, 0]
# order [63, 65, 2, 55, 0] picked in dist 144 taking route [0, 0, 30, 31, 9, 47, 0]
# order [15, 32, 70, 0, 0] picked in dist 150 taking route [0, 0, 0, 5, 6, 48, 0]
# order [19, 6, 30, 67, 0] picked in dist 90 taking route [0, 0, 8, 33, 13, 14, 0]
# order [49, 70, 35, 21, 0] picked in dist 168 taking route [0, 0, 3, 5, 15, 59, 0]
# order [51, 8, 9, 85, 0] picked in dist 168 taking route [0, 0, 29, 10, 72, 86, 0]
# order [33, 71, 0, 0, 0] picked in dist 150 taking route [0, 0, 0, 0, 4, 24, 0]
# order [28, 0, 0, 0, 0] picked in dist 126 taking route [0, 0, 0, 0, 0, 20, 0]
# order [70, 0, 0, 0, 0] picked in dist 36 taking route [0, 0, 0, 0, 0, 5, 0]
# order [55, 18, 23, 78, 9] picked in dist 168 taking route [0, 27, 30, 7, 72, 70, 0]
# order [35, 0, 0, 0, 0] picked in dist 24 taking route [0, 0, 0, 0, 0, 3, 0]
# order [84, 18, 72, 48, 6] picked in dist 144 taking route [0, 7, 14, 41, 44, 23, 0]
# order [70, 4, 71, 34, 76] picked in dist 114 taking route [0, 1, 4, 5, 11, 18, 0]
# order [13, 51, 38, 57, 0] picked in dist 138 taking route [0, 0, 10, 34, 39, 22, 0]
# order [32, 35, 37, 78, 0] picked in dist 150 taking route [0, 0, 27, 3, 43, 48, 0]
# order [2, 0, 0, 0, 0] picked in dist 60 taking route [0, 0, 0, 0, 0, 9, 0]
# order [58, 18, 10, 0, 0] picked in dist 132 taking route [0, 0, 0, 7, 12, 21, 0]
# order [51, 10, 0, 0, 0] picked in dist 132 taking route [0, 0, 0, 0, 10, 21, 0]
# order [71, 33, 89, 63, 0] picked in dist 168 taking route [0, 0, 4, 31, 24, 57, 0]
# order [49, 38, 83, 73, 44] picked in dist 168 taking route [0, 35, 15, 17, 22, 85, 0]
# order [1, 79, 34, 12, 0] picked in dist 126 taking route [0, 0, 1, 32, 77, 58, 0]
# order [71, 32, 44, 30, 67] picked in dist 150 taking route [0, 4, 8, 35, 13, 48, 0]
# order [74, 51, 18, 67, 35] picked in dist 138 taking route [0, 3, 7, 10, 13, 46, 0]
# order [58, 28, 59, 88, 6] picked in dist 168 taking route [0, 12, 14, 38, 20, 64, 0]
# order [50, 71, 0, 0, 0] picked in dist 102 taking route [0, 0, 0, 0, 4, 16, 0]
# order [48, 43, 0, 0, 0] picked in dist 144 taking route [0, 0, 0, 0, 28, 23, 0]
# order [19, 27, 50, 43, 67] picked in dist 168 taking route [0, 28, 33, 13, 16, 63, 0]
# order [59, 32, 20, 70, 0] picked in dist 168 taking route [0, 0, 49, 5, 38, 48, 0]
# order [47, 20, 45, 51, 43] picked in dist 180 taking route [0, 49, 28, 10, 36, 60, 0]
# order [11, 70, 4, 47, 0] picked in dist 120 taking route [0, 0, 5, 36, 18, 19, 0]
# order [51, 0, 0, 0, 0] picked in dist 66 taking route [0, 0, 0, 0, 0, 10, 0]
# order [43, 0, 0, 0, 0] picked in dist 30 taking route [0, 0, 0, 0, 0, 28, 0]
# order [80, 15, 79, 32, 58] picked in dist 168 taking route [0, 6, 12, 48, 69, 58, 0]
# order [22, 18, 0, 0, 0] picked in dist 144 taking route [0, 0, 0, 0, 7, 62, 0]
# order [47, 0, 0, 0, 0] picked in dist 78 taking route [0, 0, 0, 0, 0, 36, 0]
# order [71, 0, 0, 0, 0] picked in dist 30 taking route [0, 0, 0, 0, 0, 4, 0]
# order [38, 22, 0, 0, 0] picked in dist 126 taking route [0, 0, 0, 0, 62, 91, 0]
# order [58, 76, 19, 0, 0] picked in dist 78 taking route [0, 0, 0, 33, 11, 12, 0]
# order [84, 60, 0, 0, 0] picked in dist 126 taking route [0, 0, 0, 0, 26, 44, 0]
# order [49, 44, 59, 78, 52] picked in dist 96 taking route [0, 25, 27, 35, 38, 15, 0]
# order [2, 6, 48, 67, 14] picked in dist 168 taking route [0, 9, 13, 14, 23, 71, 0]
# order [72, 31, 15, 52, 18] picked in dist 108 taking route [0, 25, 2, 6, 7, 41, 0]
# order [76, 15, 78, 18, 31] picked in dist 72 taking route [0, 2, 27, 6, 7, 11, 0]
# order [52, 55, 0, 0, 0] picked in dist 42 taking route [0, 0, 0, 0, 25, 30, 0]
# order [20, 0, 0, 0, 0] picked in dist 18 taking route [0, 0, 0, 0, 0, 49, 0]
# order [36, 76, 55, 18, 11] picked in dist 168 taking route [0, 30, 7, 11, 19, 68, 0]
# order [70, 18, 0, 0, 0] picked in dist 48 taking route [0, 0, 0, 0, 5, 7, 0]
# order [11, 16, 63, 18, 0] picked in dist 156 taking route [0, 0, 52, 7, 31, 19, 0]
# order [31, 0, 0, 0, 0] picked in dist 18 taking route [0, 0, 0, 0, 0, 2, 0]
# order [4, 0, 0, 0, 0] picked in dist 114 taking route [0, 0, 0, 0, 0, 18, 0]
# order [22, 18, 71, 77, 48] picked in dist 168 taking route [0, 4, 7, 23, 62, 55, 0]
# order [1, 0, 0, 0, 0] picked in dist 54 taking route [0, 0, 0, 0, 0, 32, 0]
# order [70, 32, 67, 25, 21] picked in dist 168 taking route [0, 5, 13, 48, 59, 78, 0]
# order [67, 63, 32, 31, 72] picked in dist 150 taking route [0, 2, 31, 13, 41, 48, 0]
# order [67, 70, 2, 55, 0] picked in dist 84 taking route [0, 0, 5, 30, 9, 13, 0]
# order [59, 30, 54, 10, 58] picked in dist 168 taking route [0, 8, 12, 38, 21, 66, 0]
# order [76, 0, 0, 0, 0] picked in dist 72 taking route [0, 0, 0, 0, 0, 11, 0]
# order [12, 0, 0, 0, 0] picked in dist 42 taking route [0, 0, 0, 0, 0, 77, 0]
# order [52, 34, 0, 0, 0] picked in dist 12 taking route [0, 0, 0, 0, 1, 25, 0]
# order [27, 6, 0, 0, 0] picked in dist 168 taking route [0, 0, 0, 0, 14, 63, 0]
# order [76, 83, 0, 0, 0] picked in dist 108 taking route [0, 0, 0, 0, 11, 17, 0]
# order [31, 75, 22, 63, 59] picked in dist 186 taking route [0, 2, 31, 38, 74, 62, 0]
# order [70, 10, 50, 21, 67] picked in dist 168 taking route [0, 5, 13, 16, 21, 59, 0]
# order [27, 55, 34, 64, 0] picked in dist 168 taking route [0, 0, 1, 30, 45, 63, 0]
# order [1, 66, 69, 0, 0] picked in dist 126 taking route [0, 0, 0, 50, 32, 40, 0]
# order [31, 70, 15, 16, 50] picked in dist 138 taking route [0, 2, 5, 6, 16, 52, 0]
# order [70, 31, 66, 22, 44] picked in dist 168 taking route [0, 2, 5, 35, 40, 62, 0]
# order [55, 79, 76, 0, 0] picked in dist 144 taking route [0, 0, 0, 30, 11, 58, 0]
# order [2, 31, 67, 48, 28] picked in dist 144 taking route [0, 2, 9, 13, 20, 23, 0]
# order [4, 55, 44, 0, 0] picked in dist 114 taking route [0, 0, 0, 30, 35, 18, 0]
# order [33, 44, 48, 2, 67] picked in dist 150 taking route [0, 9, 35, 13, 23, 24, 0]
# order [14, 1, 34, 44, 35] picked in dist 168 taking route [0, 1, 3, 32, 35, 71, 0]
# order [18, 71, 0, 0, 0] picked in dist 48 taking route [0, 0, 0, 0, 4, 7, 0]
# order [34, 70, 48, 66, 6] picked in dist 144 taking route [0, 1, 5, 14, 40, 23, 0]
# order [35, 28, 39, 4, 50] picked in dist 126 taking route [0, 3, 37, 16, 18, 20, 0]
# order [43, 11, 0, 0, 0] picked in dist 120 taking route [0, 0, 0, 0, 28, 19, 0]
# order [22, 59, 30, 71, 0] picked in dist 168 taking route [0, 0, 4, 8, 38, 62, 0]
# order [60, 15, 47, 33, 0] picked in dist 150 taking route [0, 0, 26, 6, 36, 24, 0]
# order [66, 71, 35, 16, 15] picked in dist 138 taking route [0, 3, 4, 6, 40, 52, 0]
# order [82, 30, 77, 55, 20] picked in dist 114 taking route [0, 49, 55, 56, 30, 8, 0]
# order [60, 34, 4, 0, 0] picked in dist 114 taking route [0, 0, 0, 1, 26, 18, 0]
# order [68, 51, 70, 31, 0] picked in dist 96 taking route [0, 0, 2, 5, 10, 51, 0]
# order [28, 71, 2, 40, 18] picked in dist 168 taking route [0, 4, 7, 9, 20, 79, 0]
# order [68, 0, 0, 0, 0] picked in dist 30 taking route [0, 0, 0, 0, 0, 51, 0]
# order [59, 35, 60, 70, 66] picked in dist 102 taking route [0, 26, 3, 5, 38, 40, 0]
# order [47, 69, 51, 44, 0] picked in dist 102 taking route [0, 0, 50, 10, 35, 36, 0]
# order [18, 10, 50, 77, 34] picked in dist 168 taking route [0, 1, 7, 16, 21, 55, 0]
# order [55, 87, 11, 51, 19] picked in dist 168 taking route [0, 30, 33, 10, 19, 61, 0]
# order [58, 49, 0, 0, 0] picked in dist 96 taking route [0, 0, 0, 0, 12, 15, 0]
# order [4, 15, 68, 59, 1] picked in dist 144 taking route [0, 51, 6, 32, 38, 18, 0]
# order [34, 2, 0, 0, 0] picked in dist 60 taking route [0, 0, 0, 0, 1, 9, 0]
# order [71, 34, 0, 0, 0] picked in dist 30 taking route [0, 0, 0, 0, 1, 4, 0]
# order [52, 0, 0, 0, 0] picked in dist 12 taking route [0, 0, 0, 0, 0, 25, 0]
# order [5, 52, 69, 44, 0] picked in dist 204 taking route [0, 0, 25, 50, 35, 67, 0]
# order [8, 2, 90, 0, 0] picked in dist 108 taking route [0, 0, 0, 29, 9, 54, 0]
# order [15, 0, 0, 0, 0] picked in dist 42 taking route [0, 0, 0, 0, 0, 6, 0]
# order [78, 79, 0, 0, 0] picked in dist 96 taking route [0, 0, 0, 0, 27, 58, 0]
# order [49, 0, 0, 0, 0] picked in dist 96 taking route [0, 0, 0, 0, 0, 15, 0]
# order [21, 78, 55, 57, 83] picked in dist 168 taking route [0, 27, 30, 39, 17, 59, 0]
# order [19, 65, 53, 70, 67] picked in dist 174 taking route [0, 75, 5, 33, 13, 47, 0]
# order [49, 34, 18, 35, 0] picked in dist 96 taking route [0, 0, 1, 3, 7, 15, 0]
# order [35, 44, 71, 69, 0] picked in dist 96 taking route [0, 0, 50, 3, 4, 35, 0]
# order [69, 70, 0, 0, 0] picked in dist 60 taking route [0, 0, 0, 0, 50, 5, 0]
# order [6, 58, 83, 0, 0] picked in dist 108 taking route [0, 0, 0, 12, 14, 17, 0]
# order [76, 0, 0, 0, 0] picked in dist 72 taking route [0, 0, 0, 0, 0, 11, 0]
# order [35, 50, 10, 21, 0] picked in dist 168 taking route [0, 0, 3, 16, 21, 59, 0]
# order [33, 90, 77, 70, 31] picked in dist 168 taking route [0, 2, 5, 54, 55, 92, 0]
# order [35, 15, 1, 30, 6] picked in dist 90 taking route [0, 3, 6, 8, 32, 14, 0]
# order [44, 43, 8, 50, 71] picked in dist 102 taking route [0, 4, 28, 29, 35, 16, 0]
# order [49, 11, 71, 34, 28] picked in dist 126 taking route [0, 1, 4, 15, 19, 20, 0]
# order [59, 34, 15, 2, 46] picked in dist 114 taking route [0, 1, 6, 9, 38, 42, 0]
# order [58, 0, 0, 0, 0] picked in dist 78 taking route [0, 0, 0, 0, 0, 12, 0]
# order [47, 0, 0, 0, 0] picked in dist 78 taking route [0, 0, 0, 0, 0, 36, 0]
# order [37, 30, 0, 0, 0] picked in dist 120 taking route [0, 0, 0, 0, 8, 43, 0]
# order [15, 5, 33, 2, 0] picked in dist 168 taking route [0, 0, 6, 9, 24, 67, 0]
# order [35, 10, 58, 63, 0] picked in dist 132 taking route [0, 0, 3, 31, 12, 21, 0]
# order [50, 13, 67, 49, 31] picked in dist 102 taking route [0, 2, 34, 13, 15, 16, 0]
# order [10, 0, 0, 0, 0] picked in dist 132 taking route [0, 0, 0, 0, 0, 21, 0]
# order [10, 55, 31, 71, 0] picked in dist 132 taking route [0, 0, 2, 4, 30, 21, 0]
# order [78, 0, 0, 0, 0] picked in dist 24 taking route [0, 0, 0, 0, 0, 27, 0]
# order [30, 90, 44, 65, 0] picked in dist 192 taking route [0, 0, 54, 8, 35, 47, 0]
# order [67, 0, 0, 0, 0] picked in dist 84 taking route [0, 0, 0, 0, 0, 13, 0]
# order [50, 34, 66, 35, 51] picked in dist 102 taking route [0, 1, 3, 10, 40, 16, 0]
# order [50, 64, 11, 0, 0] picked in dist 132 taking route [0, 0, 0, 16, 19, 45, 0]
# order [69, 0, 0, 0, 0] picked in dist 24 taking route [0, 0, 0, 0, 0, 50, 0]
# order [51, 0, 0, 0, 0] picked in dist 66 taking route [0, 0, 0, 0, 0, 10, 0]
# order [28, 38, 60, 0, 0] picked in dist 138 taking route [0, 0, 0, 26, 20, 22, 0]
# order [46, 71, 0, 0, 0] picked in dist 114 taking route [0, 0, 0, 0, 4, 42, 0]
# order [72, 31, 34, 76, 0] picked in dist 108 taking route [0, 0, 1, 2, 11, 41, 0]
# order [11, 79, 54, 6, 35] picked in dist 168 taking route [0, 3, 14, 19, 66, 58, 0]
# order [34, 22, 11, 59, 76] picked in dist 168 taking route [0, 1, 11, 38, 19, 62, 0]
# order [29, 0, 0, 0, 0] picked in dist 42 taking route [0, 0, 0, 0, 0, 53, 0]
# order [13, 78, 76, 16, 52] picked in dist 108 taking route [0, 25, 27, 34, 11, 52, 0]
# order [70, 82, 15, 49, 18] picked in dist 156 taking route [0, 5, 6, 7, 15, 56, 0]
# order [88, 0, 0, 0, 0] picked in dist 108 taking route [0, 0, 0, 0, 0, 64, 0]
# order [74, 22, 30, 0, 0] picked in dist 168 taking route [0, 0, 0, 8, 46, 62, 0]
# order [28, 50, 30, 67, 18] picked in dist 126 taking route [0, 7, 8, 13, 16, 20, 0]
# order [69, 0, 0, 0, 0] picked in dist 24 taking route [0, 0, 0, 0, 0, 50, 0]
# order [50, 49, 0, 0, 0] picked in dist 102 taking route [0, 0, 0, 0, 15, 16, 0]
# order [90, 39, 45, 0, 0] picked in dist 168 taking route [0, 0, 0, 54, 60, 37, 0]
# order [15, 31, 0, 0, 0] picked in dist 42 taking route [0, 0, 0, 0, 2, 6, 0]
# order [30, 5, 0, 0, 0] picked in dist 168 taking route [0, 0, 0, 0, 8, 67, 0]
# order [46, 59, 0, 0, 0] picked in dist 114 taking route [0, 0, 0, 0, 38, 42, 0]
# order [59, 0, 0, 0, 0] picked in dist 90 taking route [0, 0, 0, 0, 0, 38, 0]
# order [2, 0, 0, 0, 0] picked in dist 60 taking route [0, 0, 0, 0, 0, 9, 0]
# order [31, 55, 67, 30, 70] picked in dist 84 taking route [0, 2, 5, 30, 8, 13, 0]
# order [71, 18, 74, 19, 0] picked in dist 138 taking route [0, 0, 4, 7, 33, 46, 0]
# order [87, 50, 71, 0, 0] picked in dist 168 taking route [0, 0, 0, 4, 16, 61, 0]
# order [50, 70, 60, 51, 68] picked in dist 132 taking route [0, 26, 5, 10, 16, 51, 0]
# order [52, 0, 0, 0, 0] picked in dist 12 taking route [0, 0, 0, 0, 0, 25, 0]
# order [65, 43, 58, 0, 0] picked in dist 144 taking route [0, 0, 0, 28, 12, 47, 0]
# order [11, 0, 0, 0, 0] picked in dist 120 taking route [0, 0, 0, 0, 0, 19, 0]
# order [11, 51, 31, 19, 0] picked in dist 120 taking route [0, 0, 2, 33, 10, 19, 0]
# order [67, 0, 0, 0, 0] picked in dist 84 taking route [0, 0, 0, 0, 0, 13, 0]
# order [76, 71, 72, 0, 0] picked in dist 108 taking route [0, 0, 0, 4, 11, 41, 0]
# order [35, 4, 30, 0, 0] picked in dist 114 taking route [0, 0, 0, 3, 8, 18, 0]
# order [31, 58, 0, 0, 0] picked in dist 78 taking route [0, 0, 0, 0, 2, 12, 0]
# order [31, 0, 0, 0, 0] picked in dist 18 taking route [0, 0, 0, 0, 0, 2, 0]
# order [36, 31, 60, 77, 30] picked in dist 186 taking route [0, 26, 2, 8, 55, 68, 0]
# order [72, 57, 58, 75, 15] picked in dist 132 taking route [0, 74, 6, 12, 39, 41, 0]
# order [29, 1, 6, 51, 0] picked in dist 132 taking route [0, 0, 53, 32, 10, 14, 0]
# order [88, 72, 6, 0, 0] picked in dist 168 taking route [0, 0, 0, 14, 41, 64, 0]
# order [57, 77, 60, 39, 31] picked in dist 150 taking route [0, 2, 26, 37, 39, 55, 0]
# order [6, 30, 49, 31, 0] picked in dist 96 taking route [0, 0, 2, 8, 14, 15, 0]
# order [70, 2, 0, 0, 0] picked in dist 60 taking route [0, 0, 0, 0, 5, 9, 0]
# order [46, 76, 50, 58, 67] picked in dist 114 taking route [0, 11, 12, 13, 16, 42, 0]
# order [28, 89, 88, 60, 6] picked in dist 168 taking route [0, 26, 14, 20, 64, 57, 0]
# order [43, 28, 0, 0, 0] picked in dist 126 taking route [0, 0, 0, 0, 28, 20, 0]
# order [4, 50, 28, 43, 0] picked in dist 126 taking route [0, 0, 28, 16, 18, 20, 0]
# order [27, 51, 10, 48, 8] picked in dist 168 taking route [0, 29, 10, 21, 23, 63, 0]
# order [90, 83, 1, 38, 15] picked in dist 168 taking route [0, 6, 32, 17, 22, 54, 0]
# order [58, 0, 0, 0, 0] picked in dist 78 taking route [0, 0, 0, 0, 0, 12, 0]
# order [31, 29, 83, 45, 74] picked in dist 168 taking route [0, 53, 60, 94, 46, 17, 0]
# order [77, 19, 72, 0, 0] picked in dist 162 taking route [0, 0, 0, 55, 33, 41, 0]
# order [76, 35, 70, 60, 4] picked in dist 114 taking route [0, 26, 3, 5, 11, 18, 0]
# order [27, 0, 0, 0, 0] picked in dist 102 taking route [0, 0, 0, 0, 0, 63, 0]
# order [67, 8, 58, 0, 0] picked in dist 84 taking route [0, 0, 0, 29, 12, 13, 0]
# order [66, 0, 0, 0, 0] picked in dist 102 taking route [0, 0, 0, 0, 0, 40, 0]
# order [83, 55, 72, 18, 0] picked in dist 108 taking route [0, 0, 30, 7, 41, 17, 0]
# order [65, 2, 0, 0, 0] picked in dist 144 taking route [0, 0, 0, 0, 9, 47, 0]
# order [38, 51, 10, 0, 0] picked in dist 138 taking route [0, 0, 0, 10, 21, 22, 0]
# order [58, 30, 49, 56, 34] picked in dist 126 taking route [0, 1, 73, 8, 12, 15, 0]
# order [23, 0, 0, 0, 0] picked in dist 144 taking route [0, 0, 0, 0, 0, 70, 0]
# order [58, 0, 0, 0, 0] picked in dist 78 taking route [0, 0, 0, 0, 0, 12, 0]
# order [24, 58, 28, 71, 0] picked in dist 168 taking route [0, 0, 4, 12, 20, 65, 0]
# order [31, 11, 25, 6, 2] picked in dist 168 taking route [0, 2, 9, 14, 19, 78, 0]
# order [58, 4, 90, 39, 0] picked in dist 162 taking route [0, 0, 54, 12, 37, 18, 0]
# order [30, 89, 83, 27, 15] picked in dist 168 taking route [0, 6, 8, 17, 63, 57, 0]
# order [30, 35, 0, 0, 0] picked in dist 54 taking route [0, 0, 0, 0, 3, 8, 0]
# order [71, 11, 35, 45, 68] picked in dist 168 taking route [0, 51, 60, 93, 19, 4, 0]
# order [18, 76, 72, 71, 36] picked in dist 168 taking route [0, 4, 7, 11, 41, 68, 0]
# order [2, 31, 0, 0, 0] picked in dist 60 taking route [0, 0, 0, 0, 2, 9, 0]
# order [74, 0, 0, 0, 0] picked in dist 138 taking route [0, 0, 0, 0, 0, 46, 0]
# order [31, 61, 30, 76, 0] picked in dist 108 taking route [0, 0, 2, 8, 11, 76, 0]
# order [88, 34, 30, 58, 15] picked in dist 168 taking route [0, 1, 6, 8, 12, 64, 0]
# order [6, 2, 38, 23, 4] picked in dist 168 taking route [0, 9, 14, 18, 22, 70, 0]
# order [34, 65, 63, 15, 0] picked in dist 144 taking route [0, 0, 1, 6, 31, 47, 0]
# order [76, 31, 34, 4, 0] picked in dist 114 taking route [0, 0, 1, 2, 11, 18, 0]
# order [6, 21, 39, 0, 0] picked in dist 168 taking route [0, 0, 0, 59, 37, 14, 0]
# order [64, 30, 52, 18, 71] picked in dist 132 taking route [0, 25, 4, 7, 8, 45, 0]
# order [30, 51, 0, 0, 0] picked in dist 66 taking route [0, 0, 0, 0, 8, 10, 0]
# order [79, 51, 0, 0, 0] picked in dist 138 taking route [0, 0, 0, 0, 10, 58, 0]
# order [50, 0, 0, 0, 0] picked in dist 102 taking route [0, 0, 0, 0, 0, 16, 0]
# order [4, 74, 6, 43, 0] picked in dist 138 taking route [0, 0, 28, 14, 18, 46, 0]
# order [83, 31, 71, 43, 0] picked in dist 108 taking route [0, 0, 2, 28, 4, 17, 0]
# order [13, 45, 31, 2, 10] picked in dist 168 taking route [0, 2, 9, 34, 21, 60, 0]
# order [48, 0, 0, 0, 0] picked in dist 144 taking route [0, 0, 0, 0, 0, 23, 0]
# order [48, 71, 0, 0, 0] picked in dist 144 taking route [0, 0, 0, 0, 4, 23, 0]
# order [60, 90, 0, 0, 0] picked in dist 66 taking route [0, 0, 0, 0, 26, 54, 0]
# order [65, 2, 64, 30, 34] picked in dist 144 taking route [0, 1, 8, 9, 45, 47, 0]
# order [82, 55, 44, 0, 0] picked in dist 132 taking route [0, 0, 0, 30, 35, 56, 0]
# order [76, 2, 54, 0, 0] picked in dist 168 taking route [0, 0, 0, 9, 11, 66, 0]
# order [30, 0, 0, 0, 0] picked in dist 54 taking route [0, 0, 0, 0, 0, 8, 0]
# order [25, 55, 82, 30, 0] picked in dist 114 taking route [0, 0, 30, 8, 78, 56, 0]
# order [8, 76, 0, 0, 0] picked in dist 72 taking route [0, 0, 0, 0, 29, 11, 0]
# order [8, 78, 38, 67, 76] picked in dist 138 taking route [0, 27, 29, 11, 13, 22, 0]
# order [49, 0, 0, 0, 0] picked in dist 96 taking route [0, 0, 0, 0, 0, 15, 0]
# order [76, 33, 2, 71, 34] picked in dist 150 taking route [0, 1, 4, 9, 11, 24, 0]
# order [18, 71, 6, 66, 0] picked in dist 102 taking route [0, 0, 4, 7, 14, 40, 0]
# order [44, 0, 0, 0, 0] picked in dist 72 taking route [0, 0, 0, 0, 0, 35, 0]
# order [15, 34, 78, 6, 55] picked in dist 90 taking route [0, 1, 27, 30, 6, 14, 0]
# order [19, 33, 49, 10, 0] picked in dist 150 taking route [0, 0, 33, 15, 21, 24, 0]
# order [77, 53, 43, 0, 0] picked in dist 84 taking route [0, 0, 0, 28, 75, 55, 0]
# order [12, 77, 2, 45, 18] picked in dist 144 taking route [0, 77, 55, 60, 7, 9, 0]
# order [2, 80, 52, 4, 41] picked in dist 168 taking route [0, 25, 9, 18, 69, 83, 0]
# order [82, 35, 45, 63, 0] picked in dist 132 taking route [0, 0, 3, 31, 56, 60, 0]
# order [53, 67, 32, 4, 28] picked in dist 180 taking route [0, 75, 13, 18, 20, 48, 0]
# order [33, 30, 70, 44, 8] picked in dist 150 taking route [0, 29, 5, 8, 35, 24, 0]
# order [31, 15, 47, 70, 72] picked in dist 108 taking route [0, 2, 5, 6, 36, 41, 0]
# order [16, 71, 34, 50, 0] picked in dist 168 taking route [0, 0, 1, 4, 52, 16, 0]
# order [78, 62, 63, 51, 89] picked in dist 132 taking route [0, 27, 31, 10, 80, 57, 0]
# order [78, 12, 44, 15, 35] picked in dist 114 taking route [0, 3, 27, 6, 35, 77, 0]
# order [28, 74, 34, 43, 0] picked in dist 138 taking route [0, 0, 1, 28, 20, 46, 0]
# order [30, 49, 38, 0, 0] picked in dist 138 taking route [0, 0, 0, 8, 15, 22, 0]
# order [90, 77, 19, 39, 2] picked in dist 138 taking route [0, 54, 55, 9, 33, 37, 0]
# order [49, 70, 71, 2, 19] picked in dist 96 taking route [0, 4, 5, 33, 9, 15, 0]
# order [82, 34, 35, 0, 0] picked in dist 84 taking route [0, 0, 0, 1, 3, 56, 0]
# order [89, 46, 2, 16, 52] picked in dist 168 taking route [0, 25, 9, 42, 95, 57, 0]
# order [35, 43, 30, 0, 0] picked in dist 54 taking route [0, 0, 0, 3, 28, 8, 0]
# order [71, 10, 0, 0, 0] picked in dist 132 taking route [0, 0, 0, 0, 4, 21, 0]
# order [34, 55, 28, 31, 70] picked in dist 126 taking route [0, 1, 2, 5, 30, 20, 0]
# order [31, 0, 0, 0, 0] picked in dist 18 taking route [0, 0, 0, 0, 0, 2, 0]
# order [78, 0, 0, 0, 0] picked in dist 24 taking route [0, 0, 0, 0, 0, 27, 0]
# order [15, 34, 59, 0, 0] picked in dist 90 taking route [0, 0, 0, 1, 6, 38, 0]
# order [13, 64, 35, 15, 88] picked in dist 168 taking route [0, 3, 6, 34, 45, 64, 0]
# order [14, 87, 8, 35, 0] picked in dist 186 taking route [0, 0, 3, 29, 61, 71, 0]
# order [50, 1, 54, 70, 74] picked in dist 168 taking route [0, 5, 32, 16, 46, 66, 0]
# order [35, 68, 31, 18, 34] picked in dist 78 taking route [0, 1, 2, 3, 7, 51, 0]
# order [18, 72, 0, 0, 0] picked in dist 108 taking route [0, 0, 0, 0, 7, 41, 0]
# order [71, 0, 0, 0, 0] picked in dist 30 taking route [0, 0, 0, 0, 0, 4, 0]
# order [12, 82, 34, 0, 0] picked in dist 72 taking route [0, 0, 0, 1, 77, 56, 0]
# order [46, 88, 44, 13, 0] picked in dist 168 taking route [0, 0, 34, 35, 42, 64, 0]
# order [47, 46, 2, 18, 58] picked in dist 114 taking route [0, 7, 9, 12, 36, 42, 0]
# order [38, 52, 84, 0, 0] picked in dist 138 taking route [0, 0, 0, 25, 44, 22, 0]
# order [32, 19, 88, 78, 0] picked in dist 168 taking route [0, 0, 27, 33, 48, 64, 0]
# order [55, 0, 0, 0, 0] picked in dist 42 taking route [0, 0, 0, 0, 0, 30, 0]
# order [34, 0, 0, 0, 0] picked in dist 12 taking route [0, 0, 0, 0, 0, 1, 0]
# order [20, 21, 65, 84, 6] picked in dist 168 taking route [0, 49, 59, 47, 44, 14, 0]
# order [71, 32, 0, 0, 0] picked in dist 150 taking route [0, 0, 0, 0, 4, 48, 0]
# order [65, 0, 0, 0, 0] picked in dist 144 taking route [0, 0, 0, 0, 0, 47, 0]
# order [65, 33, 90, 35, 0] picked in dist 168 taking route [0, 0, 54, 93, 24, 47, 0]
# order [84, 64, 50, 57, 20] picked in dist 150 taking route [0, 49, 39, 16, 44, 45, 0]
# order [43, 78, 0, 0, 0] picked in dist 30 taking route [0, 0, 0, 0, 27, 28, 0]
# order [30, 64, 74, 31, 0] picked in dist 138 taking route [0, 0, 2, 8, 45, 46, 0]
# order [3, 71, 58, 65, 76] picked in dist 168 taking route [0, 4, 11, 12, 47, 82, 0]
# order [35, 70, 4, 10, 34] picked in dist 132 taking route [0, 1, 3, 5, 18, 21, 0]
# order [43, 70, 83, 47, 8] picked in dist 108 taking route [0, 28, 29, 5, 36, 17, 0]
# order [66, 78, 83, 80, 89] picked in dist 168 taking route [0, 27, 40, 17, 69, 57, 0]
# order [34, 0, 0, 0, 0] picked in dist 12 taking route [0, 0, 0, 0, 0, 1, 0]
# order [2, 89, 50, 30, 0] picked in dist 168 taking route [0, 0, 8, 9, 16, 57, 0]
# order [9, 13, 77, 71, 51] picked in dist 168 taking route [0, 4, 10, 34, 72, 55, 0]
# order [65, 31, 49, 15, 76] picked in dist 144 taking route [0, 2, 6, 11, 15, 47, 0]
# order [48, 59, 71, 35, 68] picked in dist 168 taking route [0, 51, 93, 96, 23, 38, 0]
# order [45, 0, 0, 0, 0] picked in dist 84 taking route [0, 0, 0, 0, 0, 60, 0]
# order [38, 0, 0, 0, 0] picked in dist 126 taking route [0, 0, 0, 0, 0, 91, 0]
# order [49, 23, 0, 0, 0] picked in dist 168 taking route [0, 0, 0, 0, 15, 70, 0]
# order [83, 0, 0, 0, 0] picked in dist 108 taking route [0, 0, 0, 0, 0, 17, 0]
# order [69, 32, 58, 60, 34] picked in dist 192 taking route [0, 1, 26, 50, 12, 48, 0]
# order [87, 52, 58, 51, 72] picked in dist 168 taking route [0, 25, 10, 12, 41, 61, 0]
# order [76, 46, 30, 0, 0] picked in dist 114 taking route [0, 0, 0, 8, 11, 42, 0]
# order [8, 58, 37, 39, 51] picked in dist 120 taking route [0, 29, 10, 12, 37, 43, 0]
# order [34, 52, 43, 31, 1] picked in dist 54 taking route [0, 25, 1, 2, 28, 32, 0]
# order [18, 0, 0, 0, 0] picked in dist 48 taking route [0, 0, 0, 0, 0, 7, 0]
# order [72, 52, 30, 34, 0] picked in dist 108 taking route [0, 0, 1, 25, 8, 41, 0]
# order [38, 29, 70, 53, 71] picked in dist 162 taking route [0, 4, 5, 75, 53, 91, 0]
# order [8, 3, 35, 39, 0] picked in dist 156 taking route [0, 0, 3, 29, 37, 82, 0]
# order [33, 43, 58, 0, 0] picked in dist 150 taking route [0, 0, 0, 28, 12, 24, 0]
# order [25, 20, 49, 71, 51] picked in dist 144 taking route [0, 49, 78, 4, 10, 15, 0]
# order [4, 34, 16, 66, 11] picked in dist 168 taking route [0, 1, 52, 40, 18, 19, 0]
# order [6, 1, 24, 77, 0] picked in dist 168 taking route [0, 0, 55, 65, 14, 32, 0]
# order [90, 9, 76, 0, 0] picked in dist 168 taking route [0, 0, 0, 54, 72, 11, 0]
# order [38, 58, 21, 83, 0] picked in dist 168 taking route [0, 0, 59, 22, 17, 12, 0]
# order [32, 35, 0, 0, 0] picked in dist 150 taking route [0, 0, 0, 0, 3, 48, 0]
# order [5, 2, 49, 76, 35] picked in dist 168 taking route [0, 3, 9, 11, 15, 67, 0]
# order [1, 66, 52, 56, 0] picked in dist 132 taking route [0, 0, 25, 73, 32, 40, 0]
# order [34, 10, 0, 0, 0] picked in dist 132 taking route [0, 0, 0, 0, 1, 21, 0]
# order [46, 21, 19, 6, 35] picked in dist 168 taking route [0, 3, 33, 14, 42, 59, 0]
# order [6, 28, 0, 0, 0] picked in dist 126 taking route [0, 0, 0, 0, 14, 20, 0]
# order [35, 49, 5, 3, 0] picked in dist 168 taking route [0, 0, 3, 15, 67, 82, 0]
# order [35, 36, 38, 13, 0] picked in dist 168 taking route [0, 0, 3, 34, 22, 68, 0]
# order [89, 76, 0, 0, 0] picked in dist 138 taking route [0, 0, 0, 0, 57, 11, 0]
# order [71, 15, 2, 0, 0] picked in dist 60 taking route [0, 0, 0, 4, 6, 9, 0]
# order [70, 22, 60, 2, 0] picked in dist 156 taking route [0, 0, 26, 5, 9, 62, 0]
# order [37, 10, 0, 0, 0] picked in dist 132 taking route [0, 0, 0, 0, 43, 21, 0]
# order [11, 0, 0, 0, 0] picked in dist 120 taking route [0, 0, 0, 0, 0, 19, 0]
# order [55, 76, 79, 51, 0] picked in dist 144 taking route [0, 0, 30, 10, 11, 58, 0]
# order [78, 35, 0, 0, 0] picked in dist 24 taking route [0, 0, 0, 0, 3, 27, 0]
# order [76, 88, 68, 0, 0] picked in dist 168 taking route [0, 0, 0, 51, 64, 11, 0]
# order [18, 47, 67, 8, 0] picked in dist 84 taking route [0, 0, 29, 7, 36, 13, 0]
# order [18, 53, 15, 11, 49] picked in dist 150 taking route [0, 75, 6, 7, 15, 19, 0]
# order [56, 15, 63, 0, 0] picked in dist 66 taking route [0, 0, 0, 73, 6, 31, 0]
# order [49, 6, 31, 0, 0] picked in dist 96 taking route [0, 0, 0, 2, 14, 15, 0]
# order [33, 83, 76, 30, 50] picked in dist 150 taking route [0, 8, 11, 16, 17, 24, 0]
# order [38, 0, 0, 0, 0] picked in dist 126 taking route [0, 0, 0, 0, 0, 91, 0]
# order [50, 11, 0, 0, 0] picked in dist 120 taking route [0, 0, 0, 0, 16, 19, 0]
# order [34, 13, 44, 4, 60] picked in dist 114 taking route [0, 1, 26, 34, 35, 18, 0]
# order [29, 70, 90, 11, 38] picked in dist 204 taking route [0, 5, 53, 54, 22, 19, 0]
# order [18, 35, 0, 0, 0] picked in dist 48 taking route [0, 0, 0, 0, 3, 7, 0]
# order [2, 71, 4, 70, 28] picked in dist 126 taking route [0, 4, 5, 9, 18, 20, 0]
# order [71, 67, 15, 49, 31] picked in dist 96 taking route [0, 2, 4, 6, 13, 15, 0]
# order [72, 0, 0, 0, 0] picked in dist 108 taking route [0, 0, 0, 0, 0, 41, 0]
# order [57, 52, 74, 41, 51] picked in dist 168 taking route [0, 25, 10, 39, 46, 83, 0]
# order [49, 0, 0, 0, 0] picked in dist 96 taking route [0, 0, 0, 0, 0, 15, 0]
# order [6, 60, 80, 15, 87] picked in dist 168 taking route [0, 26, 6, 14, 69, 61, 0]
# order [18, 15, 71, 35, 0] picked in dist 48 taking route [0, 0, 3, 4, 6, 7, 0]
# order [33, 3, 22, 49, 0] picked in dist 168 taking route [0, 0, 82, 62, 24, 15, 0]
# order [1, 15, 28, 70, 87] picked in dist 168 taking route [0, 5, 6, 32, 20, 61, 0]
# order [83, 46, 18, 56, 0] picked in dist 132 taking route [0, 0, 73, 7, 17, 42, 0]
# order [84, 79, 18, 64, 0] picked in dist 168 taking route [0, 0, 7, 44, 45, 58, 0]
# order [33, 76, 68, 0, 0] picked in dist 180 taking route [0, 0, 0, 51, 11, 24, 0]
# order [49, 51, 83, 74, 0] picked in dist 138 taking route [0, 0, 10, 15, 17, 46, 0]
# order [6, 89, 33, 51, 0] picked in dist 168 taking route [0, 0, 10, 14, 24, 57, 0]
# order [15, 64, 18, 83, 0] picked in dist 132 taking route [0, 0, 6, 7, 17, 45, 0]
# order [66, 0, 0, 0, 0] picked in dist 102 taking route [0, 0, 0, 0, 0, 40, 0]
# order [19, 0, 0, 0, 0] picked in dist 60 taking route [0, 0, 0, 0, 0, 33, 0]
# order [52, 0, 0, 0, 0] picked in dist 12 taking route [0, 0, 0, 0, 0, 25, 0]
# order [35, 67, 23, 61, 46] picked in dist 168 taking route [0, 76, 93, 70, 42, 13, 0]
# order [1, 0, 0, 0, 0] picked in dist 54 taking route [0, 0, 0, 0, 0, 32, 0]
# order [31, 52, 83, 0, 0] picked in dist 108 taking route [0, 0, 0, 25, 2, 17, 0]
# order [31, 28, 6, 51, 2] picked in dist 126 taking route [0, 2, 9, 10, 14, 20, 0]
# order [82, 31, 2, 67, 65] picked in dist 168 taking route [0, 2, 9, 13, 47, 56, 0]
# order [67, 2, 55, 79, 47] picked in dist 156 taking route [0, 30, 9, 36, 13, 58, 0]
# order [35, 70, 0, 0, 0] picked in dist 36 taking route [0, 0, 0, 0, 3, 5, 0]
# order [11, 30, 71, 29, 0] picked in dist 162 taking route [0, 0, 4, 8, 19, 53, 0]
# order [2, 0, 0, 0, 0] picked in dist 60 taking route [0, 0, 0, 0, 0, 9, 0]
# order [2, 43, 15, 0, 0] picked in dist 60 taking route [0, 0, 0, 28, 6, 9, 0]
# order [76, 0, 0, 0, 0] picked in dist 72 taking route [0, 0, 0, 0, 0, 11, 0]
# order [71, 51, 33, 4, 11] picked in dist 150 taking route [0, 4, 10, 18, 19, 24, 0]
# order [67, 31, 63, 35, 50] picked in dist 102 taking route [0, 2, 3, 31, 13, 16, 0]
# order [48, 47, 70, 10, 0] picked in dist 144 taking route [0, 0, 5, 36, 21, 23, 0]
# order [15, 83, 38, 6, 0] picked in dist 138 taking route [0, 0, 6, 14, 17, 22, 0]
# order [65, 20, 18, 0, 0] picked in dist 162 taking route [0, 0, 0, 49, 7, 47, 0]
# order [32, 47, 76, 58, 49] picked in dist 150 taking route [0, 11, 12, 36, 15, 48, 0]
# order [8, 67, 78, 51, 0] picked in dist 84 taking route [0, 0, 27, 29, 10, 13, 0]
# order [48, 10, 34, 0, 0] picked in dist 144 taking route [0, 0, 0, 1, 21, 23, 0]
# order [70, 50, 35, 37, 89] picked in dist 168 taking route [0, 3, 5, 16, 43, 57, 0]
# order [48, 0, 0, 0, 0] picked in dist 144 taking route [0, 0, 0, 0, 0, 23, 0]
# order [49, 34, 0, 0, 0] picked in dist 96 taking route [0, 0, 0, 0, 1, 15, 0]
# order [4, 51, 0, 0, 0] picked in dist 114 taking route [0, 0, 0, 0, 10, 18, 0]
# order [1, 76, 0, 0, 0] picked in dist 72 taking route [0, 0, 0, 0, 32, 11, 0]
# order [67, 31, 60, 0, 0] picked in dist 84 taking route [0, 0, 0, 26, 2, 13, 0]
# order [28, 0, 0, 0, 0] picked in dist 126 taking route [0, 0, 0, 0, 0, 20, 0]
# order [39, 29, 16, 0, 0] picked in dist 126 taking route [0, 0, 0, 52, 53, 37, 0]
# order [2, 11, 1, 76, 0] picked in dist 120 taking route [0, 0, 32, 9, 11, 19, 0]
# order [29, 30, 48, 70, 0] picked in dist 168 taking route [0, 0, 5, 8, 23, 53, 0]
# order [19, 34, 35, 51, 64] picked in dist 132 taking route [0, 1, 3, 33, 10, 45, 0]
# order [74, 0, 0, 0, 0] picked in dist 138 taking route [0, 0, 0, 0, 0, 46, 0]
# order [44, 19, 30, 59, 0] picked in dist 90 taking route [0, 0, 8, 33, 35, 38, 0]
# order [83, 55, 51, 21, 0] picked in dist 168 taking route [0, 0, 30, 10, 17, 59, 0]
# order [9, 51, 72, 0, 0] picked in dist 168 taking route [0, 0, 0, 10, 41, 72, 0]
# order [63, 6, 49, 0, 0] picked in dist 96 taking route [0, 0, 0, 31, 14, 15, 0]
# order [57, 11, 29, 34, 10] picked in dist 186 taking route [0, 1, 53, 39, 19, 21, 0]
# order [31, 83, 1, 28, 35] picked in dist 126 taking route [0, 2, 3, 32, 17, 20, 0]
# order [70, 0, 0, 0, 0] picked in dist 36 taking route [0, 0, 0, 0, 0, 5, 0]
# order [76, 35, 2, 58, 25] picked in dist 126 taking route [0, 3, 9, 11, 12, 78, 0]
# order [51, 50, 0, 0, 0] picked in dist 102 taking route [0, 0, 0, 0, 10, 16, 0]
# order [34, 35, 60, 6, 76] picked in dist 90 taking route [0, 1, 26, 3, 11, 14, 0]
# order [30, 0, 0, 0, 0] picked in dist 54 taking route [0, 0, 0, 0, 0, 8, 0]
# order [35, 58, 76, 31, 13] picked in dist 78 taking route [0, 2, 3, 34, 11, 12, 0]
# order [68, 78, 33, 0, 0] picked in dist 156 taking route [0, 0, 0, 27, 51, 92, 0]
# order [28, 50, 61, 2, 70] picked in dist 162 taking route [0, 5, 9, 16, 20, 76, 0]
# order [50, 89, 83, 52, 0] picked in dist 180 taking route [0, 0, 25, 57, 17, 16, 0]
# order [46, 0, 0, 0, 0] picked in dist 114 taking route [0, 0, 0, 0, 0, 42, 0]
# order [31, 2, 6, 35, 48] picked in dist 144 taking route [0, 2, 3, 9, 14, 23, 0]
# order [25, 0, 0, 0, 0] picked in dist 48 taking route [0, 0, 0, 0, 0, 78, 0]
# order [1, 0, 0, 0, 0] picked in dist 54 taking route [0, 0, 0, 0, 0, 32, 0]
# order [35, 62, 18, 34, 50] picked in dist 162 taking route [0, 1, 3, 7, 16, 80, 0]
# order [69, 71, 78, 0, 0] picked in dist 54 taking route [0, 0, 0, 27, 4, 50, 0]
# order [4, 31, 33, 38, 51] picked in dist 150 taking route [0, 2, 10, 18, 22, 24, 0]
# order [82, 76, 30, 2, 0] picked in dist 132 taking route [0, 0, 8, 9, 11, 56, 0]
# order [16, 31, 0, 0, 0] picked in dist 54 taking route [0, 0, 0, 0, 2, 52, 0]
# order [82, 67, 18, 4, 48] picked in dist 168 taking route [0, 7, 13, 18, 23, 56, 0]
# order [60, 34, 0, 0, 0] picked in dist 18 taking route [0, 0, 0, 0, 1, 26, 0]
# order [37, 83, 77, 34, 78] picked in dist 198 taking route [0, 1, 27, 55, 17, 43, 0]
# order [33, 0, 0, 0, 0] picked in dist 132 taking route [0, 0, 0, 0, 0, 92, 0]
# order [11, 51, 34, 30, 0] picked in dist 120 taking route [0, 0, 1, 8, 10, 19, 0]
# order [10, 35, 38, 24, 0] picked in dist 168 taking route [0, 0, 3, 21, 22, 65, 0]
# order [1, 11, 34, 50, 0] picked in dist 120 taking route [0, 0, 1, 32, 16, 19, 0]
# order [18, 34, 49, 1, 0] picked in dist 96 taking route [0, 0, 1, 7, 32, 15, 0]
# order [29, 13, 8, 10, 48] picked in dist 168 taking route [0, 29, 34, 21, 23, 53, 0]
# order [35, 38, 33, 31, 0] picked in dist 144 taking route [0, 0, 91, 92, 93, 94, 0]
# order [55, 30, 34, 76, 68] picked in dist 102 taking route [0, 1, 30, 8, 11, 51, 0]
# order [8, 31, 71, 64, 33] picked in dist 150 taking route [0, 2, 4, 29, 45, 24, 0]
# order [15, 2, 1, 8, 0] picked in dist 60 taking route [0, 0, 29, 6, 32, 9, 0]
# order [52, 76, 71, 0, 0] picked in dist 72 taking route [0, 0, 0, 25, 4, 11, 0]
# order [18, 8, 35, 67, 0] picked in dist 84 taking route [0, 0, 3, 29, 7, 13, 0]
# order [34, 82, 0, 0, 0] picked in dist 72 taking route [0, 0, 0, 0, 1, 56, 0]
# order [49, 0, 0, 0, 0] picked in dist 96 taking route [0, 0, 0, 0, 0, 15, 0]
# order [8, 33, 0, 0, 0] picked in dist 150 taking route [0, 0, 0, 0, 29, 24, 0]
# order [48, 71, 11, 37, 70] picked in dist 144 taking route [0, 4, 5, 43, 19, 23, 0]
# order [6, 0, 0, 0, 0] picked in dist 90 taking route [0, 0, 0, 0, 0, 14, 0]
# order [34, 74, 6, 18, 67] picked in dist 138 taking route [0, 1, 7, 13, 14, 46, 0]
# order [10, 6, 0, 0, 0] picked in dist 132 taking route [0, 0, 0, 0, 14, 21, 0]
# order [57, 70, 64, 14, 18] picked in dist 168 taking route [0, 5, 7, 39, 45, 71, 0]
# order [35, 66, 30, 0, 0] picked in dist 102 taking route [0, 0, 0, 3, 8, 40, 0]
# order [35, 10, 34, 58, 2] picked in dist 132 taking route [0, 1, 3, 9, 12, 21, 0]
# order [70, 4, 44, 33, 18] picked in dist 150 taking route [0, 5, 7, 35, 18, 24, 0]
# order [32, 51, 59, 69, 0] picked in dist 174 taking route [0, 0, 50, 10, 38, 48, 0]
# order [31, 0, 0, 0, 0] picked in dist 18 taking route [0, 0, 0, 0, 0, 2, 0]
# order [36, 1, 54, 38, 0] picked in dist 168 taking route [0, 0, 32, 22, 68, 66, 0]
# order [49, 50, 76, 60, 0] picked in dist 102 taking route [0, 0, 26, 11, 15, 16, 0]
# order [90, 56, 15, 70, 71] picked in dist 90 taking route [0, 73, 54, 4, 5, 6, 0]
# order [16, 0, 0, 0, 0] picked in dist 36 taking route [0, 0, 0, 0, 0, 52, 0]
# order [21, 0, 0, 0, 0] picked in dist 78 taking route [0, 0, 0, 0, 0, 59, 0]
# order [30, 34, 86, 0, 0] picked in dist 138 taking route [0, 0, 0, 1, 8, 84, 0]
# order [37, 47, 63, 83, 0] picked in dist 120 taking route [0, 0, 31, 36, 17, 43, 0]
# order [31, 70, 58, 0, 0] picked in dist 78 taking route [0, 0, 0, 2, 5, 12, 0]
# order [6, 83, 79, 27, 31] picked in dist 168 taking route [0, 2, 14, 17, 63, 58, 0]
# order [76, 39, 6, 0, 0] picked in dist 90 taking route [0, 0, 0, 11, 37, 14, 0]
# order [34, 18, 52, 13, 0] picked in dist 66 taking route [0, 0, 25, 1, 7, 34, 0]
# order [32, 30, 53, 78, 0] picked in dist 222 taking route [0, 0, 27, 8, 75, 48, 0]
# order [44, 68, 0, 0, 0] picked in dist 102 taking route [0, 0, 0, 0, 51, 35, 0]
# order [74, 0, 0, 0, 0] picked in dist 138 taking route [0, 0, 0, 0, 0, 46, 0]
# order [58, 50, 47, 51, 0] picked in dist 102 taking route [0, 0, 10, 36, 12, 16, 0]
# order [31, 1, 70, 71, 0] picked in dist 54 taking route [0, 0, 2, 4, 5, 32, 0]
# order [20, 51, 0, 0, 0] picked in dist 84 taking route [0, 0, 0, 0, 49, 10, 0]
# order [83, 0, 0, 0, 0] picked in dist 108 taking route [0, 0, 0, 0, 0, 17, 0]
# order [50, 2, 0, 0, 0] picked in dist 102 taking route [0, 0, 0, 0, 9, 16, 0]
# ...
# order [50, 6, 36, 9, 0] picked in dist 168 taking route [0, 0, 14, 16, 72, 68, 0]
# order [65, 34, 71, 11, 72] picked in dist 144 taking route [0, 1, 4, 41, 19, 47, 0]
# order [30, 0, 0, 0, 0] picked in dist 54 taking route [0, 0, 0, 0, 0, 8, 0]
# order [15, 8, 72, 44, 66] picked in dist 108 taking route [0, 29, 6, 35, 40, 41, 0]
# order [18, 33, 58, 71, 0] picked in dist 150 taking route [0, 0, 4, 7, 12, 24, 0]
# order [75, 71, 18, 51, 0] picked in dist 90 taking route [0, 0, 74, 4, 7, 10, 0]
# order [38, 50, 6, 45, 0] picked in dist 168 taking route [0, 0, 60, 22, 16, 14, 0]
# order [70, 67, 4, 34, 6] picked in dist 114 taking route [0, 1, 5, 13, 14, 18, 0]
# order [70, 71, 0, 0, 0] picked in dist 36 taking route [0, 0, 0, 0, 4, 5, 0]
# order [43, 34, 0, 0, 0] picked in dist 30 taking route [0, 0, 0, 0, 1, 28, 0]
# order [51, 4, 70, 13, 11] picked in dist 120 taking route [0, 5, 34, 10, 18, 19, 0]
# order [72, 24, 43, 0, 0] picked in dist 168 taking route [0, 0, 0, 28, 41, 65, 0]
# order [16, 0, 0, 0, 0] picked in dist 36 taking route [0, 0, 0, 0, 0, 52, 0]
# order [37, 57, 31, 30, 67] picked in dist 120 taking route [0, 2, 8, 13, 39, 43, 0]
# order [82, 15, 34, 71, 46] picked in dist 168 taking route [0, 1, 4, 6, 42, 56, 0]
# order [18, 51, 0, 0, 0] picked in dist 66 taking route [0, 0, 0, 0, 7, 10, 0]
# order [38, 35, 0, 0, 0] picked in dist 138 taking route [0, 0, 0, 0, 3, 22, 0]
# order [70, 15, 0, 0, 0] picked in dist 42 taking route [0, 0, 0, 0, 5, 6, 0]
# order [71, 34, 1, 67, 87] picked in dist 168 taking route [0, 1, 4, 32, 13, 61, 0]
# order [67, 0, 0, 0, 0] picked in dist 84 taking route [0, 0, 0, 0, 0, 13, 0]
# order [35, 0, 0, 0, 0] picked in dist 24 taking route [0, 0, 0, 0, 0, 3, 0]
# order [22, 16, 71, 51, 2] picked in dist 162 taking route [0, 4, 9, 10, 52, 62, 0]
# order [31, 10, 0, 0, 0] picked in dist 132 taking route [0, 0, 0, 0, 2, 21, 0]
# order [30, 27, 0, 0, 0] picked in dist 156 taking route [0, 0, 0, 0, 8, 63, 0]
# order [11, 0, 0, 0, 0] picked in dist 120 taking route [0, 0, 0, 0, 0, 19, 0]
# order [64, 4, 6, 0, 0] picked in dist 132 taking route [0, 0, 0, 14, 18, 45, 0]
# order [78, 35, 0, 0, 0] picked in dist 24 taking route [0, 0, 0, 0, 3, 27, 0]
# order [31, 76, 55, 83, 58] picked in dist 108 taking route [0, 2, 30, 11, 12, 17, 0]
# order [51, 35, 2, 16, 0] picked in dist 102 taking route [0, 0, 3, 9, 10, 52, 0]
# order [31, 6, 75, 83, 18] picked in dist 132 taking route [0, 2, 7, 14, 17, 74, 0]
# order [35, 2, 44, 55, 0] picked in dist 72 taking route [0, 0, 3, 30, 9, 35, 0]
# order [38, 59, 51, 83, 34] picked in dist 138 taking route [0, 1, 10, 38, 17, 22, 0]
# order [37, 38, 35, 46, 49] picked in dist 138 taking route [0, 3, 15, 42, 43, 22, 0]
# order [76, 50, 46, 21, 59] picked in dist 168 taking route [0, 11, 38, 16, 42, 59, 0]
# order [74, 0, 0, 0, 0] picked in dist 138 taking route [0, 0, 0, 0, 0, 46, 0]
# order [15, 39, 10, 0, 0] picked in dist 132 taking route [0, 0, 0, 6, 37, 21, 0]
# order [19, 0, 0, 0, 0] picked in dist 60 taking route [0, 0, 0, 0, 0, 33, 0]
# order [35, 2, 6, 0, 0] picked in dist 90 taking route [0, 0, 0, 3, 9, 14, 0]
# order [48, 11, 10, 50, 0] picked in dist 144 taking route [0, 0, 16, 19, 21, 23, 0]
# order [70, 58, 10, 0, 0] picked in dist 132 taking route [0, 0, 0, 5, 12, 21, 0]
# order [67, 16, 65, 4, 21] picked in dist 168 taking route [0, 52, 59, 47, 18, 13, 0]
# order [2, 0, 0, 0, 0] picked in dist 60 taking route [0, 0, 0, 0, 0, 9, 0]
# order [63, 50, 18, 38, 0] picked in dist 138 taking route [0, 0, 7, 31, 16, 22, 0]
# order [55, 53, 0, 0, 0] picked in dist 72 taking route [0, 0, 0, 0, 75, 30, 0]
# order [6, 35, 67, 78, 0] picked in dist 90 taking route [0, 0, 27, 3, 13, 14, 0]
# order [83, 64, 34, 49, 16] picked in dist 168 taking route [0, 1, 15, 17, 45, 95, 0]
# order [4, 71, 83, 0, 0] picked in dist 114 taking route [0, 0, 0, 4, 17, 18, 0]
# order [64, 79, 84, 0, 0] picked in dist 168 taking route [0, 0, 0, 58, 45, 44, 0]
# order [4, 0, 0, 0, 0] picked in dist 114 taking route [0, 0, 0, 0, 0, 18, 0]
# order [11, 65, 34, 70, 0] picked in dist 144 taking route [0, 0, 1, 5, 19, 47, 0]
# order [50, 0, 0, 0, 0] picked in dist 102 taking route [0, 0, 0, 0, 0, 16, 0]
# order [69, 11, 67, 15, 0] picked in dist 144 taking route [0, 0, 50, 6, 13, 19, 0]
# order [76, 78, 29, 2, 30] picked in dist 114 taking route [0, 27, 8, 9, 11, 53, 0]
# order [70, 78, 11, 0, 0] picked in dist 120 taking route [0, 0, 0, 27, 5, 19, 0]
# order [70, 52, 47, 0, 0] picked in dist 78 taking route [0, 0, 0, 25, 5, 36, 0]
# order [83, 33, 2, 34, 16] picked in dist 168 taking route [0, 1, 9, 17, 24, 95, 0]
# order [69, 35, 0, 0, 0] picked in dist 48 taking route [0, 0, 0, 0, 3, 50, 0]
# order [48, 1, 47, 70, 0] picked in dist 144 taking route [0, 0, 5, 32, 36, 23, 0]
# order [5, 0, 0, 0, 0] picked in dist 126 taking route [0, 0, 0, 0, 0, 67, 0]
# order [30, 34, 19, 27, 59] picked in dist 168 taking route [0, 1, 8, 33, 38, 63, 0]
# order [82, 33, 0, 0, 0] picked in dist 132 taking route [0, 0, 0, 0, 56, 92, 0]
# order [55, 7, 74, 90, 38] picked in dist 210 taking route [0, 30, 54, 87, 22, 46, 0]
# order [70, 34, 55, 16, 18] picked in dist 84 taking route [0, 1, 5, 30, 7, 52, 0]
# order [66, 67, 69, 0, 0] picked in dist 126 taking route [0, 0, 0, 50, 13, 40, 0]
# order [13, 34, 67, 84, 15] picked in dist 126 taking route [0, 1, 6, 34, 13, 44, 0]
# order [27, 54, 20, 35, 23] picked in dist 144 taking route [0, 49, 63, 66, 93, 70, 0]
# order [51, 84, 31, 6, 0] picked in dist 126 taking route [0, 0, 2, 10, 14, 44, 0]
# order [50, 34, 0, 0, 0] picked in dist 102 taking route [0, 0, 0, 0, 1, 16, 0]
# order [35, 48, 0, 0, 0] picked in dist 144 taking route [0, 0, 0, 0, 3, 23, 0]
# order [83, 13, 55, 11, 58] picked in dist 120 taking route [0, 30, 34, 12, 17, 19, 0]
# order [57, 34, 21, 18, 58] picked in dist 168 taking route [0, 1, 7, 12, 39, 59, 0]
# order [50, 71, 28, 30, 72] picked in dist 126 taking route [0, 4, 8, 16, 41, 20, 0]
# order [45, 76, 19, 10, 34] picked in dist 168 taking route [0, 1, 33, 11, 21, 60, 0]
# order [79, 71, 34, 48, 0] picked in dist 180 taking route [0, 0, 1, 58, 96, 23, 0]
# order [38, 33, 76, 28, 4] picked in dist 150 taking route [0, 11, 18, 20, 22, 24, 0]
# order [28, 63, 32, 0, 0] picked in dist 150 taking route [0, 0, 0, 31, 20, 48, 0]
# order [68, 37, 31, 35, 38] picked in dist 168 taking route [0, 51, 93, 94, 22, 43, 0]
# order [65, 52, 77, 0, 0] picked in dist 180 taking route [0, 0, 0, 25, 55, 47, 0]
# order [46, 39, 0, 0, 0] picked in dist 114 taking route [0, 0, 0, 0, 37, 42, 0]
# order [31, 2, 60, 0, 0] picked in dist 60 taking route [0, 0, 0, 26, 2, 9, 0]
# order [33, 6, 49, 55, 51] picked in dist 150 taking route [0, 30, 10, 14, 15, 24, 0]
# order [8, 67, 35, 4, 89] picked in dist 168 taking route [0, 3, 29, 13, 18, 57, 0]
# order [43, 0, 0, 0, 0] picked in dist 30 taking route [0, 0, 0, 0, 0, 28, 0]
# order [31, 34, 0, 0, 0] picked in dist 18 taking route [0, 0, 0, 0, 1, 2, 0]
# order [49, 15, 60, 18, 76] picked in dist 96 taking route [0, 26, 6, 7, 11, 15, 0]
# order [31, 46, 76, 71, 51] picked in dist 114 taking route [0, 2, 4, 10, 11, 42, 0]
# order [31, 0, 0, 0, 0] picked in dist 18 taking route [0, 0, 0, 0, 0, 2, 0]
# order [33, 70, 0, 0, 0] picked in dist 150 taking route [0, 0, 0, 0, 5, 24, 0]
# order [67, 58, 60, 83, 49] picked in dist 108 taking route [0, 26, 12, 13, 15, 17, 0]
# order [71, 0, 0, 0, 0] picked in dist 30 taking route [0, 0, 0, 0, 0, 4, 0]
# order [2, 23, 0, 0, 0] picked in dist 168 taking route [0, 0, 0, 0, 9, 70, 0]
# order [51, 0, 0, 0, 0] picked in dist 66 taking route [0, 0, 0, 0, 0, 10, 0]
# order [65, 28, 0, 0, 0] picked in dist 144 taking route [0, 0, 0, 0, 20, 47, 0]
# order [34, 76, 2, 43, 71] picked in dist 72 taking route [0, 1, 4, 28, 9, 11, 0]
# order [13, 16, 49, 0, 0] picked in dist 132 taking route [0, 0, 0, 52, 34, 15, 0]
# order [51, 0, 0, 0, 0] picked in dist 66 taking route [0, 0, 0, 0, 0, 10, 0]
# order [34, 60, 90, 58, 0] picked in dist 126 taking route [0, 0, 1, 26, 12, 54, 0]
# order [28, 71, 48, 18, 0] picked in dist 144 taking route [0, 0, 4, 7, 20, 23, 0]
# order [68, 90, 67, 49, 58] picked in dist 144 taking route [0, 51, 54, 12, 13, 15, 0]
# order [74, 0, 0, 0, 0] picked in dist 138 taking route [0, 0, 0, 0, 0, 46, 0]
# order [2, 0, 0, 0, 0] picked in dist 60 taking route [0, 0, 0, 0, 0, 9, 0]
# order [68, 76, 0, 0, 0] picked in dist 102 taking route [0, 0, 0, 0, 51, 11, 0]
# order [35, 15, 20, 0, 0] picked in dist 60 taking route [0, 0, 0, 49, 3, 6, 0]
# order [49, 83, 30, 52, 35] picked in dist 108 taking route [0, 25, 3, 8, 15, 17, 0]
# order [48, 39, 8, 57, 0] picked in dist 144 taking route [0, 0, 29, 37, 39, 23, 0]
# order [19, 20, 8, 44, 49] picked in dist 114 taking route [0, 49, 29, 33, 35, 15, 0]
# order [44, 31, 0, 0, 0] picked in dist 72 taking route [0, 0, 0, 0, 2, 35, 0]
# order [49, 19, 51, 83, 0] picked in dist 108 taking route [0, 0, 33, 10, 15, 17, 0]
# order [34, 40, 15, 47, 10] picked in dist 168 taking route [0, 1, 6, 36, 21, 79, 0]
# order [32, 18, 33, 47, 50] picked in dist 150 taking route [0, 7, 36, 16, 24, 48, 0]
# order [33, 0, 0, 0, 0] picked in dist 132 taking route [0, 0, 0, 0, 0, 92, 0]
# order [55, 57, 71, 31, 0] picked in dist 96 taking route [0, 0, 2, 4, 30, 39, 0]
# order [37, 78, 45, 4, 79] picked in dist 168 taking route [0, 27, 18, 43, 60, 58, 0]
# order [19, 51, 71, 68, 89] picked in dist 132 taking route [0, 51, 57, 4, 33, 10, 0]
# order [35, 74, 31, 71, 34] picked in dist 138 taking route [0, 1, 2, 3, 4, 46, 0]
# order [51, 2, 32, 6, 0] picked in dist 150 taking route [0, 0, 9, 10, 14, 48, 0]
# order [35, 0, 0, 0, 0] picked in dist 24 taking route [0, 0, 0, 0, 0, 3, 0]
# order [66, 10, 70, 31, 34] picked in dist 132 taking route [0, 1, 2, 5, 40, 21, 0]
# order [20, 0, 0, 0, 0] picked in dist 18 taking route [0, 0, 0, 0, 0, 49, 0]
# order [35, 48, 5, 31, 13] picked in dist 168 taking route [0, 2, 3, 34, 23, 67, 0]
# order [38, 0, 0, 0, 0] picked in dist 126 taking route [0, 0, 0, 0, 0, 91, 0]
# order [8, 0, 0, 0, 0] picked in dist 36 taking route [0, 0, 0, 0, 0, 29, 0]
# order [30, 39, 78, 28, 60] picked in dist 126 taking route [0, 26, 27, 8, 37, 20, 0]
# order [34, 6, 0, 0, 0] picked in dist 90 taking route [0, 0, 0, 0, 1, 14, 0]
# order [36, 58, 71, 5, 0] picked in dist 168 taking route [0, 0, 4, 12, 68, 67, 0]
# order [8, 35, 0, 0, 0] picked in dist 36 taking route [0, 0, 0, 0, 3, 29, 0]
# order [31, 51, 76, 0, 0] picked in dist 72 taking route [0, 0, 0, 2, 10, 11, 0]
# order [35, 0, 0, 0, 0] picked in dist 24 taking route [0, 0, 0, 0, 0, 3, 0]
# order [30, 0, 0, 0, 0] picked in dist 54 taking route [0, 0, 0, 0, 0, 8, 0]
# order [1, 87, 0, 0, 0] picked in dist 144 taking route [0, 0, 0, 0, 32, 61, 0]
# order [57, 32, 13, 71, 51] picked in dist 150 taking route [0, 4, 10, 34, 39, 48, 0]
# order [34, 84, 38, 89, 10] picked in dist 180 taking route [0, 1, 57, 22, 21, 44, 0]
# order [51, 10, 83, 28, 30] picked in dist 132 taking route [0, 8, 10, 17, 20, 21, 0]
# order [66, 55, 86, 35, 50] picked in dist 168 taking route [0, 3, 30, 16, 40, 84, 0]
# order [46, 90, 35, 6, 11] picked in dist 168 taking route [0, 3, 14, 42, 19, 54, 0]
# order [69, 50, 0, 0, 0] picked in dist 126 taking route [0, 0, 0, 0, 50, 16, 0]
# order [19, 86, 15, 59, 0] picked in dist 168 taking route [0, 0, 6, 33, 38, 84, 0]
# order [69, 0, 0, 0, 0] picked in dist 24 taking route [0, 0, 0, 0, 0, 50, 0]
# order [31, 46, 56, 34, 0] picked in dist 150 taking route [0, 0, 1, 2, 73, 42, 0]
# order [31, 13, 37, 0, 0] picked in dist 120 taking route [0, 0, 0, 2, 34, 43, 0]
# order [15, 0, 0, 0, 0] picked in dist 42 taking route [0, 0, 0, 0, 0, 6, 0]
# order [58, 45, 1, 0, 0] picked in dist 162 taking route [0, 0, 0, 32, 12, 60, 0]
# order [88, 63, 0, 0, 0] picked in dist 156 taking route [0, 0, 0, 0, 31, 64, 0]
# order [52, 18, 63, 0, 0] picked in dist 48 taking route [0, 0, 0, 25, 31, 7, 0]
# order [71, 31, 74, 84, 15] picked in dist 138 taking route [0, 2, 4, 6, 44, 46, 0]
# order [50, 82, 20, 77, 0] picked in dist 162 taking route [0, 0, 49, 55, 56, 16, 0]
# order [70, 0, 0, 0, 0] picked in dist 36 taking route [0, 0, 0, 0, 0, 5, 0]
# order [35, 27, 47, 67, 18] picked in dist 168 taking route [0, 3, 7, 36, 13, 63, 0]
# order [74, 64, 53, 70, 11] picked in dist 168 taking route [0, 75, 5, 19, 45, 46, 0]
# order [11, 63, 78, 18, 2] picked in dist 120 taking route [0, 27, 7, 31, 9, 19, 0]
# order [76, 0, 0, 0, 0] picked in dist 72 taking route [0, 0, 0, 0, 0, 11, 0]
# order [51, 82, 11, 0, 0] picked in dist 180 taking route [0, 0, 0, 56, 10, 19, 0]
# order [6, 8, 16, 0, 0] picked in dist 126 taking route [0, 0, 0, 52, 29, 14, 0]
# order [15, 34, 0, 0, 0] picked in dist 42 taking route [0, 0, 0, 0, 1, 6, 0]
# order [13, 70, 78, 0, 0] picked in dist 66 taking route [0, 0, 0, 27, 5, 34, 0]
# order [52, 11, 0, 0, 0] picked in dist 120 taking route [0, 0, 0, 0, 25, 19, 0]
# order [51, 43, 0, 0, 0] picked in dist 66 taking route [0, 0, 0, 0, 28, 10, 0]
# order [59, 8, 33, 18, 0] picked in dist 150 taking route [0, 0, 29, 7, 38, 24, 0]
# order [67, 0, 0, 0, 0] picked in dist 84 taking route [0, 0, 0, 0, 0, 13, 0]
# order [2, 18, 44, 33, 0] picked in dist 150 taking route [0, 0, 7, 9, 35, 24, 0]
# order [87, 0, 0, 0, 0] picked in dist 90 taking route [0, 0, 0, 0, 0, 61, 0]
# order [89, 35, 71, 1, 62] picked in dist 120 taking route [0, 3, 4, 32, 80, 57, 0]
# order [51, 66, 50, 47, 34] picked in dist 102 taking route [0, 1, 10, 36, 16, 40, 0]
# order [15, 72, 0, 0, 0] picked in dist 108 taking route [0, 0, 0, 0, 6, 41, 0]
# order [11, 70, 0, 0, 0] picked in dist 120 taking route [0, 0, 0, 0, 5, 19, 0]
# order [32, 6, 79, 34, 0] picked in dist 168 taking route [0, 0, 1, 14, 48, 58, 0]
# order [87, 60, 45, 68, 0] picked in dist 108 taking route [0, 0, 26, 51, 60, 61, 0]
# order [58, 18, 65, 39, 70] picked in dist 144 taking route [0, 5, 7, 12, 37, 47, 0]
# order [28, 15, 0, 0, 0] picked in dist 126 taking route [0, 0, 0, 0, 6, 20, 0]
# order [18, 31, 78, 63, 32] picked in dist 150 taking route [0, 2, 27, 31, 7, 48, 0]
# order [71, 35, 2, 0, 0] picked in dist 60 taking route [0, 0, 0, 3, 4, 9, 0]
# order [24, 43, 0, 0, 0] picked in dist 144 taking route [0, 0, 0, 0, 28, 65, 0]
# order [68, 77, 12, 74, 4] picked in dist 168 taking route [0, 51, 77, 55, 46, 18, 0]
# order [71, 6, 36, 0, 0] picked in dist 168 taking route [0, 0, 0, 4, 14, 68, 0]
# order [52, 30, 79, 34, 0] picked in dist 126 taking route [0, 0, 1, 25, 8, 58, 0]
# order [60, 0, 0, 0, 0] picked in dist 18 taking route [0, 0, 0, 0, 0, 26, 0]
# order [50, 34, 0, 0, 0] picked in dist 102 taking route [0, 0, 0, 0, 1, 16, 0]
# order [35, 34, 18, 60, 0] picked in dist 48 taking route [0, 0, 1, 26, 3, 7, 0]
# order [71, 0, 0, 0, 0] picked in dist 30 taking route [0, 0, 0, 0, 0, 4, 0]
# order [6, 33, 55, 0, 0] picked in dist 150 taking route [0, 0, 0, 30, 14, 24, 0]
# order [28, 21, 38, 33, 15] picked in dist 168 taking route [0, 6, 20, 22, 24, 59, 0]
# order [33, 71, 35, 51, 0] picked in dist 150 taking route [0, 0, 3, 4, 10, 24, 0]
# order [15, 6, 78, 35, 0] picked in dist 90 taking route [0, 0, 3, 27, 6, 14, 0]
# order [57, 48, 44, 77, 52] picked in dist 168 taking route [0, 25, 35, 39, 23, 55, 0]
# order [49, 48, 63, 34, 0] picked in dist 144 taking route [0, 0, 1, 31, 15, 23, 0]
# order [76, 22, 31, 5, 70] picked in dist 168 taking route [0, 2, 5, 11, 67, 62, 0]
# order [4, 31, 0, 0, 0] picked in dist 114 taking route [0, 0, 0, 0, 2, 18, 0]
# order [50, 71, 83, 89, 49] picked in dist 168 taking route [0, 4, 15, 16, 17, 57, 0]
# order [44, 0, 0, 0, 0] picked in dist 72 taking route [0, 0, 0, 0, 0, 35, 0]
# order [1, 60, 0, 0, 0] picked in dist 54 taking route [0, 0, 0, 0, 26, 32, 0]
# order [29, 1, 70, 71, 76] picked in dist 114 taking route [0, 4, 5, 32, 11, 53, 0]
# order [48, 52, 84, 58, 30] picked in dist 144 taking route [0, 25, 8, 12, 44, 23, 0]
# order [60, 46, 35, 0, 0] picked in dist 114 taking route [0, 0, 0, 26, 3, 42, 0]
# order [8, 43, 70, 77, 31] picked in dist 90 taking route [0, 2, 28, 5, 29, 55, 0]
# order [46, 0, 0, 0, 0] picked in dist 114 taking route [0, 0, 0, 0, 0, 42, 0]
# order [90, 23, 64, 35, 0] picked in dist 168 taking route [0, 0, 54, 93, 70, 45, 0]
# order [4, 35, 0, 0, 0] picked in dist 114 taking route [0, 0, 0, 0, 3, 18, 0]

# %%
print(results[0])
# Out:
# 238062

# %%
def slightlyGreedy_ConstructionHeuristic(Distances):
    refilledProducts = False
    tempProducts = [i for i in range(1, 91)]

    tempDistances = addTemporaryFarAwayShelves(Distances)

    normalShelves = [0]*96
    extraShelves = [x for x in range(1, 91)]

    tempAllocations = normalShelves.copy() + extraShelves.copy()

    for shelf in range(96):

        mostReduced = np.inf
        bestP = None
        
        tempShelves = tempAllocations.copy()
        baseline = q1_function(tempShelves, tempDistances)[0]

        for p in tempProducts:
            
            tempShelves = tempAllocations.copy()
            tempShelves[shelf] = p

            newobj = q1_function(tempShelves, tempDistances)

            reduction = newobj[0] - baseline

            if reduction <= mostReduced:
                bestP = p
                mostReduced = reduction

        tempAllocations[shelf] = bestP

        tempProducts.remove(bestP)

        if refilledProducts == False:
            indexOfBestP_onExtraShelf = tempAllocations[96:].index(bestP)
            del tempAllocations[indexOfBestP_onExtraShelf+96]

        if len(tempProducts) == 0:
            tempProducts = [i for i in range(1, 91)]
            refilledProducts = True

        

        print(f"Assigned product {bestP} -> shelf {shelf+1}")

    return tempAllocations
